# %% [markdown]
# # COSTO UNITARIO PROMEDIO

# %% [markdown]
# ### OBTENCION COSTO DEL PRODUCTO

# %%
import xmlrpc.client
import pandas as pd

username = "juan.cano@donsson.com"
password = "1000285668"
url = "https://donsson.com"
db = "Donsson_produccion"

common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
uid = common.authenticate(db, username, password, {})
models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")


# 1. Obtener las órdenes de producción ya cerradas (hechas por manufactura)
ordenes_produccion = models.execute_kw(
    db, uid, password,
    'mrp.production', 'search_read',
    [[('state', '=', 'done')]],   # Solo cerradas
    {'fields': ['id', 'product_id', 'product_qty']}
)

# 2. Extraer los productos únicos de esas órdenes
ids_productos_manu = list({op['product_id'][0] for op in ordenes_produccion if op.get('product_id')})

# 3. Leer los productos manufacturados que correspondan a DONSSON
productos_manu = models.execute_kw(
    db, uid, password,
    'product.product', 'read',
    [ids_productos_manu],
    {'fields': ['id', 'name', 'standard_price', 'catalogo_codigo_fab', 'qty_available']}
)

# 4. Filtrar solo marca DONSSON
productos_donsson_manu = [p for p in productos_manu if p.get('catalogo_codigo_fab') == 'DONSSON']



productos_manu = pd.DataFrame(productos_manu) # productos con costo entre los manufacturados

# %%
productos_manu = productos_manu.rename(columns={
    'name': 'producto',
    'standard_price': 'costo_estandar_promedio',
    'qty_available': 'cantidad_disponible'
})

pd.set_option("display.max_colwidth", None)
productos_manu = productos_manu[["producto","costo_estandar_promedio","cantidad_disponible"]]

# %% [markdown]
# #### Buscador para casos especiales productos

# %%
productos_manu[productos_manu["producto"].str.contains("DA2919", case=False, na=False)]
# Out:
#                            producto  costo_estandar_promedio  \
# 291  DA2919  FILTROAIRE CHEV. LV150                  45119.8
#
#      cantidad_disponible
# 291                128.0

# %% [markdown]
# ### OBTENCION COSTO DE ORDEN DE PRODUCCION

# %%
# 1. Obtener las órdenes de producción ya cerradas (hechas por manufactura)
ordenes_produccion = models.execute_kw(
    db, uid, password,
    'mrp.production', 'search_read',
    [[('state', '=', 'done')]],   # Solo cerradas
    {'fields': ['id','name'#'date_start'
                , 'product_id', 'product_qty','valor_unitario_mrp','date_finished']}
)



ops = pd.DataFrame(ordenes_produccion) # todas las OP cerradas

# %%
ops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12012 entries, 0 to 12011
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   valor_unitario_mrp  12012 non-null  float64
#  1   product_id          12012 non-null  object
#  2   date_finished       12012 non-null  object
#  3   product_qty         12012 non-null  float64
#  4   id                  12012 non-null  int64
#  5   name                12012 non-null  object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 563.2+ KB

# %%
ops.head()
# Out:
#    valor_unitario_mrp  \
# 0             7481.39
# 1           104539.15
# 2            15743.62
# 3            11909.12
# 4            12435.46
#
#                                                                                  product_id  \
# 0                 [17320, [DAB02995025] DA2995 FILTRO AIRE TOYOTA, MAZDA,FORD (025 DA2995)]
# 1                            [50343, [DAB08276025] DA8276 FILTRO AIRE - FOTON (025 DA8276)]
# 2    [25666, [DAB08170025] DA8170 FILTRO AIRE CAMIONES JMC CARRYING PLUS 2018 (025 DA8170)]
# 3  [17684, [DAB04783025] DA4783 FILTRO AIRE SEGURIDAD-  CHEV.FFR,FTR, HITACHI (025 DA4783)]
# 4        [17702, [DAB04864025] DA4864 FILTRO AIRE 2_ CATERPILLAR, JOHN DEERE. (025 DA4864)]
#
#          date_finished  product_qty     id     name
# 0  2018-03-28 13:00:43       1001.0   2388   O02445
# 1  2025-09-11 16:28:42          1.0  13402  MO13131
# 2  2025-09-12 14:10:02        300.0  13396  MO13125
# 3  2025-09-12 14:08:39        400.0  13395  MO13124
# 4  2025-09-12 14:07:19        100.0  13392  MO13121

# %%
ops = ops.rename(columns={

    "name" :"nombre_op",
    "product_qty":"unidades_producidas",
    "valor_unitario_mrp":"costo_unitario_op",
    "date_finished":"fecha_cierre_op"
})

# %%
import re

# 1) Quedarnos con el nombre del producto dentro de product_id
#    (Odoo devuelve [id, "nombre"])
ops['product_name_raw'] = ops['product_id'].apply(
    lambda v: v[1] if isinstance(v, (list, tuple)) and len(v) >= 2 else str(v)
)

# 2) Quitar el código entre corchetes "[...]" + espacios iniciales
# 3) Quitar todo lo que esté dentro de paréntesis "(...)" + espacios
ops['producto'] = (
    ops['product_name_raw']
      .astype(str)
      .str.replace(r'^\s*\[.*?\]\s*', '', regex=True)   # elimina "[CODE] "
      .str.replace(r'\(.*?\)', '', regex=True)          # elimina "(...)"
      .str.strip()
)

# (opcional) normalizar espacios internos
ops['producto'] = ops['producto'].str.replace(r'\s+', ' ', regex=True)

# %% [markdown]
# #### Buscador casos especiales por op

# %%
ops = ops[["producto","unidades_producidas","nombre_op","costo_unitario_op","fecha_cierre_op"]]
pd.set_option("display.max_colwidth", None)

ops[ops["producto"].str.contains("DA2983", case=False, na=False)]
# Out:
#                                 producto  unidades_producidas nombre_op  \
# 44     DA2983 FILTROAIRE MOTORES PERKINS                200.0   MO13059
# 639    DA2983 FILTROAIRE MOTORES PERKINS                250.0   MO12313
# 836    DA2983 FILTROAIRE MOTORES PERKINS                150.0   MO12113
# 1237   DA2983 FILTROAIRE MOTORES PERKINS                150.0   MO11704
# 1610   DA2983 FILTROAIRE MOTORES PERKINS                150.0   MO11292
# 2028   DA2983 FILTROAIRE MOTORES PERKINS                150.0   MO10871
# 2499   DA2983 FILTROAIRE MOTORES PERKINS                200.0   MO10367
# 3070   DA2983 FILTROAIRE MOTORES PERKINS                300.0   MO09748
# 3515   DA2983 FILTROAIRE MOTORES PERKINS                300.0   MO09266
# 3870   DA2983 FILTROAIRE MOTORES PERKINS                151.0   MO08876
# 4271   DA2983 FILTROAIRE MOTORES PERKINS                200.0   MO08426
# 4515   DA2983 FILTROAIRE MOTORES PERKINS                150.0   MO08159
# 5297   DA2983 FILTROAIRE MOTORES PERKINS                300.0   MO07311
# 5777   DA2983 FILTROAIRE MOTORES PERKINS                302.0   MO06792
# 6018   DA2983 FILTROAIRE MOTORES PERKINS                300.0   MO06517
# 6273   DA2983 FILTROAIRE MOTORES PERKINS                300.0   MO06237
# 6645   DA2983 FILTROAIRE MOTORES PERKINS                300.0   MO05845
# 6847   DA2983 FILTROAIRE MOTORES PERKINS                300.0   MO05622
# 7061   DA2983 FILTROAIRE MOTORES PERKINS                201.0   MO05388
# 7359   DA2983 FILTROAIRE MOTORES PERKINS                250.0   MO05075
# 7429   DA2983 FILTROAIRE MOTORES PERKINS                252.0   MO04995
# 7695   DA2983 FILTROAIRE MOTORES PERKINS                201.0   MO04676
# 7896   DA2983 FILTROAIRE MOTORES PERKINS                200.0   MO04416
# 8106   DA2983 FILTROAIRE MOTORES PERKINS                150.0   MO04168
# 8404   DA2983 FILTROAIRE MOTORES PERKINS                200.0   MO03849
# 8584   DA2983 FILTROAIRE MOTORES PERKINS                150.0   MO03659
# 8816   DA2983 FILTROAIRE MOTORES PERKINS                201.0   MO03417
# 9113   DA2983 FILTROAIRE MOTORES PERKINS                150.0   MO03110
# 9312   DA2983 FILTROAIRE MOTORES PERKINS                148.0   MO02899
# 9627   DA2983 FILTROAIRE MOTORES PERKINS                120.0   MO02565
# 9798   DA2983 FILTROAIRE MOTORES PERKINS                102.0   MO02388
# 9953   DA2983 FILTROAIRE MOTORES PERKINS                100.0   MO02228
# 10093  DA2983 FILTROAIRE MOTORES PERKINS                 80.0   MO02076
# 10304  DA2983 FILTROAIRE MOTORES PERKINS                 80.0   MO01841
# 10907  DA2983 FILTROAIRE MOTORES PERKINS                320.0   MO01203
# 11308  DA2983 FILTROAIRE MOTORES PERKINS                100.0   MO00777
# 11682  DA2983 FILTROAIRE MOTORES PERKINS                 80.0   MO00351
#
#        costo_unitario_op      fecha_cierre_op
# 44              10804.43  2025-09-12 13:51:18
# 639             10023.63  2025-05-07 10:11:22
# 836             11036.00  2025-03-28 07:39:47
# 1237            12236.66  2024-12-27 14:55:34
# 1610            10042.45  2024-09-27 15:55:31
# 2028            11038.63  2024-07-11 06:44:08
# 2499            11866.00  2024-04-30 15:08:05
# 3070            10816.48  2023-11-08 09:22:11
# 3515            10458.89  2023-07-26 13:46:17
# 3870            11377.29  2023-05-17 16:02:46
# 4271            13402.83  2023-02-04 11:57:28
# 4515            11963.35  2022-11-04 14:24:24
# 5297            10512.41  2022-02-28 14:04:28
# 5777             5239.36  2021-09-28 10:07:33
# 6018             4485.41  2021-07-29 16:00:30
# 6273             4396.14  2021-05-08 10:23:17
# 6645             4239.99  2021-01-15 15:04:34
# 6847             4833.45  2020-10-29 13:49:56
# 7061             4461.75  2020-09-03 09:49:04
# 7359             4677.92  2020-06-11 09:54:44
# 7429             3561.97  2020-03-22 12:50:33
# 7695             4173.97  2019-12-20 15:03:35
# 7896             4425.62  2019-10-31 10:00:49
# 8106             4650.74  2019-09-13 13:14:31
# 8404             4880.51  2019-06-17 11:52:44
# 8584             4879.29  2019-03-30 07:43:06
# 8816             3728.81  2019-01-30 15:27:26
# 9113             3555.56  2018-10-24 16:58:16
# 9312             3345.31  2018-08-30 13:28:26
# 9627             3852.50  2018-05-25 07:17:40
# 9798             4348.66  2018-03-09 13:17:27
# 9953             3827.39  2018-01-26 10:19:33
# 10093            3385.41  2017-12-06 10:13:28
# 10304            3446.74  2017-10-04 13:23:47
# 10907            3999.52  2017-04-10 10:58:53
# 11308            4250.15  2016-12-07 17:25:42
# 11682            4358.33  2016-08-08 16:00:04

# %% [markdown]
# ### Corrector matches merge

# %% [markdown]
# ### OPS DE CADA PRODUCTO

# %%
from fuzzywuzzy import process

# 1. Merge exacto
df_unido = productos_manu.merge(ops, on="producto", how="left", indicator=True)

# 2. Productos que no hicieron match exacto
no_match = df_unido[df_unido["_merge"] == "left_only"]["producto"].unique()

# 3. Lista de productos en OP
productos_ops = ops["producto"].dropna().unique()

# 4. Crear diccionario de equivalencias con fuzzy
mapeo = {}
for prod in no_match:
    mejor_match, score = process.extractOne(prod, productos_ops)
    if score >= 85:   # solo aceptamos matches muy altos
        mapeo[prod] = mejor_match

# 5. Reemplazar en productos_manu
productos_manu["producto_corr"] = productos_manu["producto"].replace(mapeo)

# 6. Nuevo merge usando los nombres corregidos
df_unido_corr = productos_manu.merge(ops, left_on="producto_corr", right_on="producto", how="left", indicator=True)
# Out:
# /home/donsson/proyectos/env/lib/python3.12/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#df_unido_corr[df_unido_corr["producto_x"].str.contains("DA2983")]

# %% [markdown]
# ### COSTO DE CADA OP

# %%
from fuzzywuzzy import process

# ==============================
# 1) Calcular costo promedio real de productos_manu
# ==============================
def calcular_costo_promedio(grupo):
    if grupo["cantidad_disponible"].sum() == 0:
        return None  # evitar división por 0
    return (grupo["costo_estandar_promedio"] * grupo["cantidad_disponible"]).sum() / grupo["cantidad_disponible"].sum()

costo_promedio = (
    productos_manu.groupby("producto")
    .apply(calcular_costo_promedio)
    .reset_index(name="costo_promedio")
)

# ==============================
# 2) Merge exacto primero (ops vs productos_manu)
# ==============================
df_ops_unido = ops.merge(costo_promedio, on="producto", how="left", indicator=True)

# ==============================
# 3) Detectar OPs sin match
# ==============================
no_match_ops = df_ops_unido[df_ops_unido["_merge"] == "left_only"]["producto"].unique()

# ==============================
# 4) Lista de productos válidos (de productos_manu)
# ==============================
productos_manu_lista = costo_promedio["producto"].dropna().unique()

# ==============================
# 5) Crear diccionario de equivalencias fuzzy
# ==============================
mapeo_ops = {}
for prod in no_match_ops:
    mejor_match, score = process.extractOne(prod, productos_manu_lista)
    if score >= 85:
        mapeo_ops[prod] = mejor_match

# ==============================
# 6) Corregir los nombres en ops
# ==============================
ops["producto_corr"] = ops["producto"].replace(mapeo_ops)

# ==============================
# 7) Merge final (con fuzzy corregido)
# ==============================
ops_con_costo = ops.merge(
    costo_promedio, left_on="producto_corr", right_on="producto", how="left"
)

# ==============================
# 8) Limpiar columnas duplicadas
# ==============================

cols_a_borrar = [c for c in ["producto_x", "producto_y"] if c in ops_con_costo.columns]
ops_con_costo = ops_con_costo.drop(columns=cols_a_borrar)

# Renombrar la corregida como "producto"
if "producto_corr" in ops_con_costo.columns:
    ops_con_costo = ops_con_costo.rename(columns={"producto_corr": "producto"})
# Out:
# /tmp/ipykernel_106576/787867308.py:13: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(calcular_costo_promedio)

# %%
ops_con_costo[ops_con_costo["producto"].str.contains("DA2983")]
# Out:
#        unidades_producidas nombre_op  costo_unitario_op      fecha_cierre_op  \
# 44                   200.0   MO13059           10804.43  2025-09-12 13:51:18
# 639                  250.0   MO12313           10023.63  2025-05-07 10:11:22
# 836                  150.0   MO12113           11036.00  2025-03-28 07:39:47
# 1237                 150.0   MO11704           12236.66  2024-12-27 14:55:34
# 1610                 150.0   MO11292           10042.45  2024-09-27 15:55:31
# 2028                 150.0   MO10871           11038.63  2024-07-11 06:44:08
# 2499                 200.0   MO10367           11866.00  2024-04-30 15:08:05
# 3070                 300.0   MO09748           10816.48  2023-11-08 09:22:11
# 3515                 300.0   MO09266           10458.89  2023-07-26 13:46:17
# 3870                 151.0   MO08876           11377.29  2023-05-17 16:02:46
# 4271                 200.0   MO08426           13402.83  2023-02-04 11:57:28
# 4515                 150.0   MO08159           11963.35  2022-11-04 14:24:24
# 5297                 300.0   MO07311           10512.41  2022-02-28 14:04:28
# 5777                 302.0   MO06792            5239.36  2021-09-28 10:07:33
# 6018                 300.0   MO06517            4485.41  2021-07-29 16:00:30
# 6273                 300.0   MO06237            4396.14  2021-05-08 10:23:17
# 6645                 300.0   MO05845            4239.99  2021-01-15 15:04:34
# 6847                 300.0   MO05622            4833.45  2020-10-29 13:49:56
# 7061                 201.0   MO05388            4461.75  2020-09-03 09:49:04
# 7359                 250.0   MO05075            4677.92  2020-06-11 09:54:44
# 7429                 252.0   MO04995            3561.97  2020-03-22 12:50:33
# 7695                 201.0   MO04676            4173.97  2019-12-20 15:03:35
# 7896                 200.0   MO04416            4425.62  2019-10-31 10:00:49
# 8106                 150.0   MO04168            4650.74  2019-09-13 13:14:31
# 8404                 200.0   MO03849            4880.51  2019-06-17 11:52:44
# 8584                 150.0   MO03659            4879.29  2019-03-30 07:43:06
# 8816                 201.0   MO03417            3728.81  2019-01-30 15:27:26
# 9113                 150.0   MO03110            3555.56  2018-10-24 16:58:16
# 9312                 148.0   MO02899            3345.31  2018-08-30 13:28:26
# 9627                 120.0   MO02565            3852.50  2018-05-25 07:17:40
# 9798                 102.0   MO02388            4348.66  2018-03-09 13:17:27
# 9953                 100.0   MO02228            3827.39  2018-01-26 10:19:33
# 10093                 80.0   MO02076            3385.41  2017-12-06 10:13:28
# 10304                 80.0   MO01841            3446.74  2017-10-04 13:23:47
# 10907                320.0   MO01203            3999.52  2017-04-10 10:58:53
# 11308                100.0   MO00777            4250.15  2016-12-07 17:25:42
# 11682                 80.0   MO00351            4358.33  2016-08-08 16:00:04
#
#                                 producto  costo_promedio
# 44     DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 639    DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 836    DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 1237   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 1610   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 2028   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 2499   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 3070   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 3515   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 3870   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 4271   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 4515   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 5297   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 5777   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 6018   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 6273   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 6645   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 6847   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 7061   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 7359   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 7429   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 7695   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 7896   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 8106   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 8404   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 8584   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 8816   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 9113   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 9312   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 9627   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 9798   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 9953   DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 10093  DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 10304  DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 10907  DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 11308  DA2983 FILTROAIRE MOTORES PERKINS        10686.95
# 11682  DA2983 FILTROAIRE MOTORES PERKINS        10686.95

# %%
ops_con_costo['diferencia'] = ops_con_costo['costo_unitario_op'] - ops_con_costo['costo_promedio']

ops_con_costo["%diferencia"] = (ops_con_costo["diferencia"] / ops_con_costo["costo_promedio"])

ops_con_costo["%_diferencia_abs"] = (ops_con_costo["diferencia"].abs() / ops_con_costo['costo_promedio'])

# %%
ops_con_costo.to_excel("ops_relacionadas.xlsx")

# %%
ops_con_costo[ops_con_costo["costo_promedio"]==0]  # Comprobamos que no quedo ninguna OP sin el costo promedio asignado
# Out:
# Empty DataFrame
# Columns: [unidades_producidas, nombre_op, costo_unitario_op, fecha_cierre_op, producto, costo_promedio, diferencia, %diferencia, %_diferencia_abs]
# Index: []

# %% [markdown]
# ### Df unido y corregido

# %%
df_unido_corr[df_unido_corr["producto_x"].str.contains("DA2983")].sample(10)
# Out:
#                              producto_x  costo_estandar_promedio  \
# 5666  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
# 5672  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
# 5683  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
# 5689  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
# 5674  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
# 5675  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
# 5684  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
# 5690  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
# 5676  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
# 5692  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
#
#       cantidad_disponible                      producto_corr  \
# 5666                367.0  DA2983 FILTROAIRE MOTORES PERKINS
# 5672                367.0  DA2983 FILTROAIRE MOTORES PERKINS
# 5683                367.0  DA2983 FILTROAIRE MOTORES PERKINS
# 5689                367.0  DA2983 FILTROAIRE MOTORES PERKINS
# 5674                367.0  DA2983 FILTROAIRE MOTORES PERKINS
# 5675                367.0  DA2983 FILTROAIRE MOTORES PERKINS
# 5684                367.0  DA2983 FILTROAIRE MOTORES PERKINS
# 5690                367.0  DA2983 FILTROAIRE MOTORES PERKINS
# 5676                367.0  DA2983 FILTROAIRE MOTORES PERKINS
# 5692                367.0  DA2983 FILTROAIRE MOTORES PERKINS
#
#                              producto_y  unidades_producidas nombre_op  \
# 5666  DA2983 FILTROAIRE MOTORES PERKINS                150.0   MO10871
# 5672  DA2983 FILTROAIRE MOTORES PERKINS                150.0   MO08159
# 5683  DA2983 FILTROAIRE MOTORES PERKINS                200.0   MO04416
# 5689  DA2983 FILTROAIRE MOTORES PERKINS                148.0   MO02899
# 5674  DA2983 FILTROAIRE MOTORES PERKINS                302.0   MO06792
# 5675  DA2983 FILTROAIRE MOTORES PERKINS                300.0   MO06517
# 5684  DA2983 FILTROAIRE MOTORES PERKINS                150.0   MO04168
# 5690  DA2983 FILTROAIRE MOTORES PERKINS                120.0   MO02565
# 5676  DA2983 FILTROAIRE MOTORES PERKINS                300.0   MO06237
# 5692  DA2983 FILTROAIRE MOTORES PERKINS                100.0   MO02228
#
#       costo_unitario_op      fecha_cierre_op _merge
# 5666           11038.63  2024-07-11 06:44:08   both
# 5672           11963.35  2022-11-04 14:24:24   both
# 5683            4425.62  2019-10-31 10:00:49   both
# 5689            3345.31  2018-08-30 13:28:26   both
# 5674            5239.36  2021-09-28 10:07:33   both
# 5675            4485.41  2021-07-29 16:00:30   both
# 5684            4650.74  2019-09-13 13:14:31   both
# 5690            3852.50  2018-05-25 07:17:40   both
# 5676            4396.14  2021-05-08 10:23:17   both
# 5692            3827.39  2018-01-26 10:19:33   both

# %%
# 1. Crear columna final de producto
df_unido_corr["producto"] = df_unido_corr["producto_corr"].fillna(df_unido_corr["producto_x"])

# 2. Eliminar columnas duplicadas
df_unido_corr = df_unido_corr.drop(columns=["producto_x", "producto_y", "producto_corr"], errors="ignore")

# 3. Eliminar duplicados de OP
df_unido_corr = df_unido_corr.drop_duplicates(subset=["nombre_op", "fecha_cierre_op", "producto"], keep="last")

# 4. Ordenar
df_limpio = df_unido_corr.sort_values(["producto", "fecha_cierre_op"], ascending=[True, False]).reset_index(drop=True)

# %%
df_limpio = df_limpio[~ (df_limpio['cantidad_disponible']==0)]  #Retirar ruido , productos sin unidades disponibles


df_limpio[df_limpio["producto"].str.contains("DA2983")]
# Out:
#       costo_estandar_promedio  cantidad_disponible  unidades_producidas  \
# 5075                 10686.95                367.0                200.0
# 5076                 10686.95                367.0                250.0
# 5077                 10686.95                367.0                150.0
# 5078                 10686.95                367.0                150.0
# 5079                 10686.95                367.0                150.0
# 5080                 10686.95                367.0                150.0
# 5081                 10686.95                367.0                200.0
# 5082                 10686.95                367.0                300.0
# 5083                 10686.95                367.0                300.0
# 5084                 10686.95                367.0                151.0
# 5085                 10686.95                367.0                200.0
# 5086                 10686.95                367.0                150.0
# 5087                 10686.95                367.0                300.0
# 5088                 10686.95                367.0                302.0
# 5089                 10686.95                367.0                300.0
# 5090                 10686.95                367.0                300.0
# 5091                 10686.95                367.0                300.0
# 5092                 10686.95                367.0                300.0
# 5093                 10686.95                367.0                201.0
# 5094                 10686.95                367.0                250.0
# 5095                 10686.95                367.0                252.0
# 5096                 10686.95                367.0                201.0
# 5097                 10686.95                367.0                200.0
# 5098                 10686.95                367.0                150.0
# 5099                 10686.95                367.0                200.0
# 5100                 10686.95                367.0                150.0
# 5101                 10686.95                367.0                201.0
# 5102                 10686.95                367.0                150.0
# 5103                 10686.95                367.0                148.0
# 5104                 10686.95                367.0                120.0
# 5105                 10686.95                367.0                102.0
# 5106                 10686.95                367.0                100.0
# 5107                 10686.95                367.0                 80.0
# 5108                 10686.95                367.0                 80.0
# 5109                 10686.95                367.0                320.0
# 5110                 10686.95                367.0                100.0
# 5111                 10686.95                367.0                 80.0
#
#      nombre_op  costo_unitario_op      fecha_cierre_op _merge  \
# 5075   MO13059           10804.43  2025-09-12 13:51:18   both
# 5076   MO12313           10023.63  2025-05-07 10:11:22   both
# 5077   MO12113           11036.00  2025-03-28 07:39:47   both
# 5078   MO11704           12236.66  2024-12-27 14:55:34   both
# 5079   MO11292           10042.45  2024-09-27 15:55:31   both
# 5080   MO10871           11038.63  2024-07-11 06:44:08   both
# 5081   MO10367           11866.00  2024-04-30 15:08:05   both
# 5082   MO09748           10816.48  2023-11-08 09:22:11   both
# 5083   MO09266           10458.89  2023-07-26 13:46:17   both
# 5084   MO08876           11377.29  2023-05-17 16:02:46   both
# 5085   MO08426           13402.83  2023-02-04 11:57:28   both
# 5086   MO08159           11963.35  2022-11-04 14:24:24   both
# 5087   MO07311           10512.41  2022-02-28 14:04:28   both
# 5088   MO06792            5239.36  2021-09-28 10:07:33   both
# 5089   MO06517            4485.41  2021-07-29 16:00:30   both
# 5090   MO06237            4396.14  2021-05-08 10:23:17   both
# 5091   MO05845            4239.99  2021-01-15 15:04:34   both
# 5092   MO05622            4833.45  2020-10-29 13:49:56   both
# 5093   MO05388            4461.75  2020-09-03 09:49:04   both
# 5094   MO05075            4677.92  2020-06-11 09:54:44   both
# 5095   MO04995            3561.97  2020-03-22 12:50:33   both
# 5096   MO04676            4173.97  2019-12-20 15:03:35   both
# 5097   MO04416            4425.62  2019-10-31 10:00:49   both
# 5098   MO04168            4650.74  2019-09-13 13:14:31   both
# 5099   MO03849            4880.51  2019-06-17 11:52:44   both
# 5100   MO03659            4879.29  2019-03-30 07:43:06   both
# 5101   MO03417            3728.81  2019-01-30 15:27:26   both
# 5102   MO03110            3555.56  2018-10-24 16:58:16   both
# 5103   MO02899            3345.31  2018-08-30 13:28:26   both
# 5104   MO02565            3852.50  2018-05-25 07:17:40   both
# 5105   MO02388            4348.66  2018-03-09 13:17:27   both
# 5106   MO02228            3827.39  2018-01-26 10:19:33   both
# 5107   MO02076            3385.41  2017-12-06 10:13:28   both
# 5108   MO01841            3446.74  2017-10-04 13:23:47   both
# 5109   MO01203            3999.52  2017-04-10 10:58:53   both
# 5110   MO00777            4250.15  2016-12-07 17:25:42   both
# 5111   MO00351            4358.33  2016-08-08 16:00:04   both
#
#                                producto
# 5075  DA2983 FILTROAIRE MOTORES PERKINS
# 5076  DA2983 FILTROAIRE MOTORES PERKINS
# 5077  DA2983 FILTROAIRE MOTORES PERKINS
# 5078  DA2983 FILTROAIRE MOTORES PERKINS
# 5079  DA2983 FILTROAIRE MOTORES PERKINS
# 5080  DA2983 FILTROAIRE MOTORES PERKINS
# 5081  DA2983 FILTROAIRE MOTORES PERKINS
# 5082  DA2983 FILTROAIRE MOTORES PERKINS
# 5083  DA2983 FILTROAIRE MOTORES PERKINS
# 5084  DA2983 FILTROAIRE MOTORES PERKINS
# 5085  DA2983 FILTROAIRE MOTORES PERKINS
# 5086  DA2983 FILTROAIRE MOTORES PERKINS
# 5087  DA2983 FILTROAIRE MOTORES PERKINS
# 5088  DA2983 FILTROAIRE MOTORES PERKINS
# 5089  DA2983 FILTROAIRE MOTORES PERKINS
# 5090  DA2983 FILTROAIRE MOTORES PERKINS
# 5091  DA2983 FILTROAIRE MOTORES PERKINS
# 5092  DA2983 FILTROAIRE MOTORES PERKINS
# 5093  DA2983 FILTROAIRE MOTORES PERKINS
# 5094  DA2983 FILTROAIRE MOTORES PERKINS
# 5095  DA2983 FILTROAIRE MOTORES PERKINS
# 5096  DA2983 FILTROAIRE MOTORES PERKINS
# 5097  DA2983 FILTROAIRE MOTORES PERKINS
# 5098  DA2983 FILTROAIRE MOTORES PERKINS
# 5099  DA2983 FILTROAIRE MOTORES PERKINS
# 5100  DA2983 FILTROAIRE MOTORES PERKINS
# 5101  DA2983 FILTROAIRE MOTORES PERKINS
# 5102  DA2983 FILTROAIRE MOTORES PERKINS
# 5103  DA2983 FILTROAIRE MOTORES PERKINS
# 5104  DA2983 FILTROAIRE MOTORES PERKINS
# 5105  DA2983 FILTROAIRE MOTORES PERKINS
# 5106  DA2983 FILTROAIRE MOTORES PERKINS
# 5107  DA2983 FILTROAIRE MOTORES PERKINS
# 5108  DA2983 FILTROAIRE MOTORES PERKINS
# 5109  DA2983 FILTROAIRE MOTORES PERKINS
# 5110  DA2983 FILTROAIRE MOTORES PERKINS
# 5111  DA2983 FILTROAIRE MOTORES PERKINS

# %%
# ===========================
# 1) Función costo real
# ===========================
def calcular_costo_real(grupo):
    # ordenar las OP por fecha (descendente: más recientes primero)
    grupo = grupo.sort_values('fecha_cierre_op', ascending=False)

    cant_disp = grupo['cantidad_disponible'].iloc[0]
    total_tomado = 0
    costo_total = 0

    for _, row in grupo.iterrows():
        if total_tomado >= cant_disp:
            break

        # ignorar OP con costo nulo o cero
        if pd.isna(row['costo_unitario_op']) or row['costo_unitario_op'] == 0:
            continue

        # Tomar lo que falta o lo que tiene esta OP
        tomar = min(row['unidades_producidas'], cant_disp - total_tomado)

        costo_total += tomar * row['costo_unitario_op']
        total_tomado += tomar

    if total_tomado == 0:
        return None

    return costo_total / total_tomado


# ===========================
# 2) Costo real por producto
# ===========================
costo_real = (
    df_limpio
    .groupby('producto')
    .apply(calcular_costo_real)
    .reset_index()
)
costo_real.columns = ['producto', 'costo_real']


# ===========================
# 3) Última fecha de producción por producto
# ===========================
ultima_fecha = (
    df_limpio.groupby('producto')['fecha_cierre_op']
    .max()
    .reset_index()
)
ultima_fecha.columns = ['producto', 'ultima_fecha_produccion']


# ===========================
# 4) Construcción resumen
# ===========================
resumen = (
    df_limpio[['producto', 'costo_estandar_promedio', 'cantidad_disponible']]
    .drop_duplicates()
    .merge(costo_real, on='producto', how='left')
    .merge(ultima_fecha, on='producto', how='left')   # <-- se agrega la fecha
)

# Diferencia entre costo real y costo estándar
resumen['diferencia'] = resumen['costo_real'] - resumen['costo_estandar_promedio']

resumen["%diferencia"] = (resumen["diferencia"] / resumen["costo_estandar_promedio"])

resumen["%_diferencia_abs"] = (resumen["diferencia"].abs() / resumen["costo_estandar_promedio"])
# Out:
# /tmp/ipykernel_106576/3487751595.py:38: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(calcular_costo_real)

# %%
resumen[resumen["costo_real"].isna()] # es un producto que tiene existencias y tiene una op pero en ella no cargaron costo unitario ejecutado fue en 2017
# Out:
#                                                producto  \
# 447  DA8021 FILTRO AIRE ASPIRADORAS INDUSTRIALES RIDGID
#
#      costo_estandar_promedio  cantidad_disponible  costo_real  \
# 447                  4856.01                  7.0         NaN
#
#     ultima_fecha_produccion  diferencia  %diferencia  %_diferencia_abs
# 447     2017-08-22 15:40:08         NaN          NaN               NaN

# %%
resumen[resumen["producto"].str.contains("DA2983", case=False, na=False)]
# Out:
#                               producto  costo_estandar_promedio  \
# 224  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
#
#      cantidad_disponible    costo_real ultima_fecha_produccion  diferencia  \
# 224                367.0  10449.134087     2025-09-12 13:51:18 -237.815913
#
#      %diferencia  %_diferencia_abs
# 224    -0.022253          0.022253

# %%
resumen.to_excel("monitoreo_costos.xlsx")

# %%
import xmlrpc.client
import pandas as pd

username = "juan.cano@donsson.com"
password = "1000285668"
url = "https://donsson.com"
db = "Donsson_produccion"

common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
uid = common.authenticate(db, username, password, {})
models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")


# 1. Obtener las órdenes de producción ya cerradas (hechas por manufactura)
precio_estandar_historico = models.execute_kw(
    db, uid, password,
    'stock.change.standard.price', 'search_read',
    [[]],   # Todo
    {'fields': ['create_date', 'product_id', 'product_qty']}
)

# %% [markdown]
# # EQUIVALENCIAS MARCAS

# %%
import xmlrpc.client
import pandas as pd

username = "juan.cano@donsson.com"
password = "1000285668"
url = "https://donsson.com"
db = "Donsson_produccion"

common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
uid = common.authenticate(db, username, password, {})
models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")

campos = models.execute_kw(
    db, uid, password,
    'product.template', 'fields_get',
    []
)

for nombre, info in campos.items():
    if info.get('type') in ('one2many', 'many2one', 'many2many'):
        print(nombre, "->", info.get('relation'))
# Out:
# write_uid -> res.users
# property_account_income -> account.account
# website_style_ids -> product.style
# product_rate -> website.product.rate
# property_stock_account_output -> account.account
# catalogo_valvula_alivio -> catalogo.product.valvula_alivio
# company_id -> res.company
# public_categ_ids -> product.public.category
# pricelist_id -> product.pricelist
# property_stock_account_input -> account.account
# bom_ids -> mrp.bom
# classprod_id -> cs.clasprod
# catalogo_material_filtrante -> catalogo.product.material_filtrante
# alternative_product_ids -> product.template
# seller_id -> res.partner
# packaging_ids -> product.packaging
# pos_categ_id -> pos.category
# seller_ids -> product.supplierinfo
# website_message_ids -> mail.message
# catalogo_marca -> catalogo.marcas
# accessory_product_ids -> product.product
# message_follower_ids -> res.partner
# attribute_line_ids -> product.attribute.line
# asset_category_id -> account.asset.category
# images -> product.image
# catalogo_rosca -> catalogo.product.rosca
# catalogo_forma -> catalogo.product.forma
# catalogo_costruccion -> catalogo.product.construccion
# partida_id -> product.partida.arancelaria
# analytics_id -> product.account.analytic.line
# property_stock_procurement -> stock.location
# uos_id -> product.uom
# create_uid -> res.users
# product_manager -> res.users
# catalogo_uso -> catalogo.product.usos
# catalogo_direccion_filtrado -> catalogo.product.direccion_filtrado
# property_stock_production -> stock.location
# taxes_ids -> res.country.state.tax
# property_stock_inventory -> stock.location
# catalogo_nivel_consumo -> catalogo.product.nivel_consumo
# catalogo_material_tapa -> catalogo.product.material_tapa
# product_tmpl_specs_ids -> product.specification
# product_variant_ids -> product.product
# uom_id -> product.uom
# catalogo_equivalencias_reffabri -> catalogo.referencia.fabricantes
# location_id -> stock.location
# message_ids -> mail.message
# uom_po_id -> product.uom
# product_class -> product.type.class
# property_account_refund -> account.account
# store_ids -> res.store
# supplier_taxes_id -> account.tax
# categ_id -> product.category
# catalogo_aplicacion_motor -> catalogo.motor.vehiculo
# route_ids -> stock.location.route
# property_account_expense -> account.account
# taxes_id -> account.tax

# %%
import xmlrpc.client
import pandas as pd

username = "juan.cano@donsson.com"
password = "1000285668"
url = "https://donsson.com"
db = "Donsson_produccion"

common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
uid = common.authenticate(db, username, password, {})
models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")


# 1) Productos básicos
productos = models.execute_kw(
    db, uid, password,
    'product.template', 'search_read',
    [[]],
    {'fields': ['id', 'name', 'default_code']}
)
df_prod = pd.DataFrame(productos).rename(columns={
    'id': 'product_id',
    'name': 'producto_nombre',
    'default_code': 'producto_codigo'
})

# 2) Equivalencias
equivalencias = models.execute_kw(
    db, uid, password,
    'catalogo.referencia.fabricantes', 'search_read',
    [[]],
    {'fields': ['id', 'name', 'tipo_marca', 'productos_referencia']}
)
df_eq = pd.DataFrame(equivalencias)

# 3) Expandir la lista de productos_referencia
df_eq = df_eq.explode('productos_referencia')
df_eq = df_eq.rename(columns={'name': 'equivalencia_ref'})

# 4) Limpiar tipo_marca (de lista [id, nombre] → solo nombre)
df_eq['marca'] = df_eq['tipo_marca'].apply(lambda x: x[1] if isinstance(x, list) else None)
df_eq['productos_referencia'] = df_eq['productos_referencia'].astype('Int64')

# 5) Merge con productos
df_final = df_eq.merge(df_prod, left_on='productos_referencia', right_on='product_id', how='left')
df_final = df_final.dropna()

# 6) Exportar a Excel
df_final[['producto_codigo', 'producto_nombre', 'equivalencia_ref', 'marca']].to_excel("equivalencias.xlsx", index=False)
print("✅ Archivo 'equivalencias.xlsx' generado correctamente")
# Out:
# ✅ Archivo 'equivalencias.xlsx' generado correctamente
