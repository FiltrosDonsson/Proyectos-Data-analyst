# %% [markdown]
# # COSTO UNITARIO PROMEDIO

# %% [markdown]
# ### OBTENCION COSTO DEL PRODUCTO

# %%
import xmlrpc.client
import pandas as pd

username = "juan.cano@donsson.com"
password = "1000285668"
url = "https://donsson.com"
db = "Donsson_produccion"

common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
uid = common.authenticate(db, username, password, {})
models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")


# 1. Obtener las órdenes de producción ya cerradas (hechas por manufactura)
ordenes_produccion = models.execute_kw(
    db, uid, password,
    'mrp.production', 'search_read',
    [[('state', '=', 'done')]],   # Solo cerradas
    {'fields': ['id', 'product_id', 'product_qty']}
)

# 2. Extraer los productos únicos de esas órdenes
ids_productos_manu = list({op['product_id'][0] for op in ordenes_produccion if op.get('product_id')})

# 3. Leer los productos manufacturados que correspondan a DONSSON
productos_manu = models.execute_kw(
    db, uid, password,
    'product.product', 'read',
    [ids_productos_manu],
    {'fields': ['id', 'name', 'standard_price', 'catalogo_codigo_fab', 'qty_available']}
)

# 4. Filtrar solo marca DONSSON
productos_donsson_manu = [p for p in productos_manu if p.get('catalogo_codigo_fab') == 'DONSSON']



productos_manu = pd.DataFrame(productos_manu) # productos con costo entre los manufacturados

# %%
productos_manu = productos_manu.rename(columns={
    'name': 'producto',
    'standard_price': 'costo_estandar_promedio',
    'qty_available': 'cantidad_disponible'
})

pd.set_option("display.max_colwidth", None)
productos_manu = productos_manu[["producto","costo_estandar_promedio","cantidad_disponible"]]

# %% [markdown]
# #### Buscador para casos especiales productos

# %%
productos_manu[productos_manu["producto"].str.contains("DA2919", case=False, na=False)]
# Out:
#                            producto  costo_estandar_promedio  \
# 293  DA2919  FILTROAIRE CHEV. LV150                  45119.8
#
#      cantidad_disponible
# 293                110.0

# %% [markdown]
# ### OBTENCION COSTO DE ORDEN DE PRODUCCION

# %%
# 1. Obtener las órdenes de producción ya cerradas (hechas por manufactura)
ordenes_produccion = models.execute_kw(
    db, uid, password,
    'mrp.production', 'search_read',
    [[('state', '=', 'done'),("date_finished" , ">" , "2022-12-31")]],   # Solo cerradas
    {'fields': ['id','name'#'date_start'
                , 'product_id', 'product_qty','valor_unitario_mrp','date_finished']}
)



ops = pd.DataFrame(ordenes_produccion) # todas las OP cerradas

# %%
ops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4592 entries, 0 to 4591
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   valor_unitario_mrp  4592 non-null   float64
#  1   product_id          4592 non-null   object
#  2   date_finished       4592 non-null   object
#  3   product_qty         4592 non-null   float64
#  4   id                  4592 non-null   int64
#  5   name                4592 non-null   object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 215.4+ KB

# %%
ops.head()
# Out:
#    valor_unitario_mrp  \
# 0            36862.48
# 1           298582.00
# 2            37570.72
# 3            25006.64
# 4            46399.38
#
#                                                                                    product_id  \
# 0  [17260, [DAB02926025] DA2926 FILTRO AIRE DONSSON - INTERNATIONAL 4300 - 7400 (025 DA2926)]
# 1               [50229, [DAB02013025] DA2013 FILTRO AIRE - KENWORTH - PETERBILT (025 DA2013)]
# 2                  [49566, [DAB08221025] DA8221 FILTRO AIRE - FAW EN DESARROLLO (025 DA8221)]
# 3                          [17226, [DAB12872025] DA2872A  FILTRO AIRE-  AGRALE (025 DA2872A)]
# 4   [17306, [DAB02982025] DA2982 FILTRO AIRE DONSSON -  IHC 7600i MOTOR CUMMINS (025 DA2982)]
#
#          date_finished  product_qty     id     name
# 0  2025-10-31 15:53:18        500.0  13670  MO13400
# 1  2025-10-28 15:57:08          1.0  13659  MO13389
# 2  2025-10-31 15:46:26         30.0  13655  MO13385
# 3  2025-10-31 14:52:53        200.0  13638  MO13368
# 4  2025-10-31 10:17:44        500.0  13637  MO13367

# %%
ops = ops.rename(columns={

    "name" :"nombre_op",
    "product_qty":"unidades_producidas",
    "valor_unitario_mrp":"costo_unitario_op",
    "date_finished":"fecha_cierre_op"
})

# %%
import re

# 1) Quedarnos con el nombre del producto dentro de product_id
#    (Odoo devuelve [id, "nombre"])
ops['product_name_raw'] = ops['product_id'].apply(
    lambda v: v[1] if isinstance(v, (list, tuple)) and len(v) >= 2 else str(v)
)

# 2) Quitar el código entre corchetes "[...]" + espacios iniciales
# 3) Quitar todo lo que esté dentro de paréntesis "(...)" + espacios
ops['producto'] = (
    ops['product_name_raw']
      .astype(str)
      .str.replace(r'^\s*\[.*?\]\s*', '', regex=True)   # elimina "[CODE] "
      .str.replace(r'\(.*?\)', '', regex=True)          # elimina "(...)"
      .str.strip()
)

# (opcional) normalizar espacios internos
ops['producto'] = ops['producto'].str.replace(r'\s+', ' ', regex=True)

# %% [markdown]
# #### Buscador casos especiales por op

# %%
ops = ops[["producto","unidades_producidas","nombre_op","costo_unitario_op","fecha_cierre_op"]]
pd.set_option("display.max_colwidth", None)

ops[ops["producto"].str.contains("DA2983", case=False, na=False)]
# Out:
#                                producto  unidades_producidas nombre_op  \
# 267   DA2983 FILTROAIRE MOTORES PERKINS                200.0   MO13059
# 884   DA2983 FILTROAIRE MOTORES PERKINS                250.0   MO12313
# 1081  DA2983 FILTROAIRE MOTORES PERKINS                150.0   MO12113
# 1482  DA2983 FILTROAIRE MOTORES PERKINS                150.0   MO11704
# 1855  DA2983 FILTROAIRE MOTORES PERKINS                150.0   MO11292
# 2273  DA2983 FILTROAIRE MOTORES PERKINS                150.0   MO10871
# 2744  DA2983 FILTROAIRE MOTORES PERKINS                200.0   MO10367
# 3315  DA2983 FILTROAIRE MOTORES PERKINS                300.0   MO09748
# 3760  DA2983 FILTROAIRE MOTORES PERKINS                300.0   MO09266
# 4115  DA2983 FILTROAIRE MOTORES PERKINS                151.0   MO08876
# 4516  DA2983 FILTROAIRE MOTORES PERKINS                200.0   MO08426
#
#       costo_unitario_op      fecha_cierre_op
# 267            10804.43  2025-09-12 13:51:18
# 884            10023.63  2025-05-07 10:11:22
# 1081           11036.00  2025-03-28 07:39:47
# 1482           12236.66  2024-12-27 14:55:34
# 1855           10042.45  2024-09-27 15:55:31
# 2273           11038.63  2024-07-11 06:44:08
# 2744           11866.00  2024-04-30 15:08:05
# 3315           10816.48  2023-11-08 09:22:11
# 3760           10458.89  2023-07-26 13:46:17
# 4115           11377.29  2023-05-17 16:02:46
# 4516           13402.83  2023-02-04 11:57:28

# %% [markdown]
# ### Corrector matches merge

# %% [markdown]
# ### OPS DE CADA PRODUCTO

# %%
from fuzzywuzzy import process

# 1. Merge exacto
df_unido = productos_manu.merge(ops, on="producto", how="left", indicator=True)

# 2. Productos que no hicieron match exacto
no_match = df_unido[df_unido["_merge"] == "left_only"]["producto"].unique()

# 3. Lista de productos en OP
productos_ops = ops["producto"].dropna().unique()

# 4. Crear diccionario de equivalencias con fuzzy
mapeo = {}
for prod in no_match:
    mejor_match, score = process.extractOne(prod, productos_ops)
    if score >= 85:   # solo aceptamos matches muy altos
        mapeo[prod] = mejor_match

# 5. Reemplazar en productos_manu
productos_manu["producto_corr"] = productos_manu["producto"].replace(mapeo)

# 6. Nuevo merge usando los nombres corregidos
df_unido_corr = productos_manu.merge(ops, left_on="producto_corr", right_on="producto", how="left", indicator=True)
# Out:
# /home/donsson/proyectos/env/lib/python3.12/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#df_unido_corr[df_unido_corr["producto_x"].str.contains("DA2983")]

# %% [markdown]
# ### COSTO DE CADA OP

# %%
from fuzzywuzzy import process

# ==============================
# 1) Calcular costo promedio real de productos_manu
# ==============================
def calcular_costo_promedio(grupo):
    if grupo["cantidad_disponible"].sum() == 0:
        return None  # evitar división por 0
    return (grupo["costo_estandar_promedio"] * grupo["cantidad_disponible"]).sum() / grupo["cantidad_disponible"].sum()

costo_promedio = (
    productos_manu.groupby("producto")
    .apply(calcular_costo_promedio)
    .reset_index(name="costo_promedio")
)

# ==============================
# 2) Merge exacto primero (ops vs productos_manu)
# ==============================
df_ops_unido = ops.merge(costo_promedio, on="producto", how="left", indicator=True)

# ==============================
# 3) Detectar OPs sin match
# ==============================
no_match_ops = df_ops_unido[df_ops_unido["_merge"] == "left_only"]["producto"].unique()

# ==============================
# 4) Lista de productos válidos (de productos_manu)
# ==============================
productos_manu_lista = costo_promedio["producto"].dropna().unique()

# ==============================
# 5) Crear diccionario de equivalencias fuzzy
# ==============================
mapeo_ops = {}
for prod in no_match_ops:
    mejor_match, score = process.extractOne(prod, productos_manu_lista)
    if score >= 85:
        mapeo_ops[prod] = mejor_match

# ==============================
# 6) Corregir los nombres en ops
# ==============================
ops["producto_corr"] = ops["producto"].replace(mapeo_ops)

# ==============================
# 7) Merge final (con fuzzy corregido)
# ==============================
ops_con_costo = ops.merge(
    costo_promedio, left_on="producto_corr", right_on="producto", how="left"
)

# ==============================
# 8) Limpiar columnas duplicadas
# ==============================

cols_a_borrar = [c for c in ["producto_x", "producto_y"] if c in ops_con_costo.columns]
ops_con_costo = ops_con_costo.drop(columns=cols_a_borrar)

# Renombrar la corregida como "producto"
if "producto_corr" in ops_con_costo.columns:
    ops_con_costo = ops_con_costo.rename(columns={"producto_corr": "producto"})


#Tarda 2 min aprox
# Out:
# /tmp/ipykernel_12077/471142342.py:13: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(calcular_costo_promedio)

# %%
ops_con_costo[ops_con_costo["producto"].str.contains("DA2570")]
# Out:
#       unidades_producidas nombre_op  costo_unitario_op      fecha_cierre_op  \
# 43                 1000.0   MO13301           14082.55  2025-10-15 16:25:56
# 153                1000.0   MO13177           13975.37  2025-09-19 14:48:48
# 282                1000.0   MO13044           13678.95  2025-08-28 13:24:48
# 366                1001.0   MO12917           13876.29  2025-08-14 16:13:39
# 456                 350.0   MO12779           18539.43  2025-07-21 09:59:32
# 486                1003.0   MO12749           12931.15  2025-07-21 09:58:51
# 642                1000.0   MO12593           13547.66  2025-06-24 09:17:15
# 726                1200.0   MO12507           13504.28  2025-05-31 11:39:40
# 783                 200.0   MO12415           19908.99  2025-05-23 10:52:57
# 834                1100.0   MO12364           14750.02  2025-05-19 14:26:17
# 906                1100.0   MO12291           15219.87  2025-04-30 15:43:49
# 1016               1100.0   MO12180           14738.64  2025-04-04 09:00:43
# 1090               1000.0   MO12104           14403.96  2025-03-20 15:13:54
# 1164               1000.0   MO12028           14266.13  2025-03-08 10:58:19
# 1312               1000.0   MO11876           14265.01  2025-02-08 11:55:24
# 1399               1003.0   MO11789           16452.56  2025-01-30 10:37:52
# 1504                501.0   MO11682           18026.89  2024-12-17 15:30:53
# 1612               1200.0   MO11574           17436.62  2024-11-27 14:50:10
# 1682               1200.0   MO11504           18849.22  2024-11-13 15:45:58
# 1786                500.0   MO11361           19504.40  2024-10-10 11:17:12
# 1787               1200.0   MO11360           14568.08  2024-10-10 11:16:27
# 1899               1000.0   MO11248           14235.13  2024-09-20 10:10:30
# 1962               1001.0   MO11184           14532.17  2024-09-08 19:51:37
# 2061               1001.0   MO11085           14557.57  2024-08-22 10:15:17
# 2195               1000.0   MO10950           14743.80  2024-07-23 08:56:26
# 2338               1001.0   MO10779           14141.23  2024-06-22 15:06:15
# 2452               1000.0   MO10664           14134.21  2024-05-30 21:29:51
# 2570               1201.0   MO10544           13837.68  2024-05-09 11:54:19
# 2694               1200.0   MO10417           12843.20  2024-04-15 15:26:49
# 2780               1200.0   MO10328           15164.06  2024-03-18 09:10:44
# 2850                402.0   MO10254           21683.69  2024-03-12 14:44:47
# 2900               1201.0   MO10198           13956.12  2024-02-27 15:55:25
# 3001               1200.0   MO10087           13186.33  2024-02-02 15:23:45
# 3071               1201.0   MO10012           15317.10  2024-01-16 16:04:10
# 3149               1202.0   MO09929           14676.77  2023-11-30 16:08:23
# 3181                200.0   MO09893           17255.72  2023-11-22 13:10:15
# 3258               1205.0   MO09808           14609.47  2023-11-10 16:01:58
# 3293                300.0   MO09772           22476.36  2023-10-31 12:55:00
# 3368               1200.0   MO09693           14431.50  2023-10-25 11:07:22
# 3473               1201.0   MO09579           14968.43  2023-09-25 15:36:46
# 3586               1206.0   MO09459           15613.44  2023-08-25 12:08:09
# 3712               1200.0   MO09318           14999.21  2023-07-31 12:39:01
# 3776                300.0   MO09250           22284.27  2023-07-14 09:08:40
# 3785               1000.0   MO09241           16021.58  2023-07-14 09:30:16
# 3855               1038.0   MO09164           15324.35  2023-06-26 11:07:13
# 3922               1204.0   MO09090           15354.07  2023-06-10 07:39:36
# 3941                601.0   MO09070           15499.75  2023-05-31 15:33:44
# 3959                602.0   MO09049           16552.58  2023-05-31 11:37:02
# 4036                600.0   MO08963           16839.07  2023-05-06 12:32:51
# 4108                600.0   MO08887           22147.88  2023-04-21 16:57:28
# 4142               1500.0   MO08848           17496.61  2023-04-22 12:13:04
# 4253               1200.0   MO08723           16120.83  2023-03-25 11:14:55
# 4275               1200.0   MO08698           17270.01  2023-03-13 09:26:10
# 4377               1200.0   MO08582           16403.32  2023-02-15 08:46:34
# 4468               1200.0   MO08481           17743.82  2023-01-31 15:53:23
# 4539               1201.0   MO08400           25954.99  2023-01-16 10:51:13
#
#                                                              producto  \
# 43           DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 153          DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 282          DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 366          DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 456   DA2570UHE FILTRO DE AIRE  ALTA EFICIENCIA - CAT - KUBOTA - CASE
# 486          DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 642          DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 726          DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 783   DA2570UHE FILTRO DE AIRE  ALTA EFICIENCIA - CAT - KUBOTA - CASE
# 834          DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 906          DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 1016         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 1090         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 1164         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 1312         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 1399         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 1504         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 1612         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 1682         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 1786  DA2570UHE FILTRO DE AIRE  ALTA EFICIENCIA - CAT - KUBOTA - CASE
# 1787         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 1899         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 1962         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 2061         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 2195         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 2338         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 2452         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 2570         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 2694         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 2780         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 2850  DA2570UHE FILTRO DE AIRE  ALTA EFICIENCIA - CAT - KUBOTA - CASE
# 2900         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 3001         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 3071         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 3149         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 3181         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 3258         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 3293  DA2570UHE FILTRO DE AIRE  ALTA EFICIENCIA - CAT - KUBOTA - CASE
# 3368         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 3473         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 3586         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 3712         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 3776  DA2570UHE FILTRO DE AIRE  ALTA EFICIENCIA - CAT - KUBOTA - CASE
# 3785         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 3855         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 3922         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 3941         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 3959         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 4036         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 4108  DA2570UHE FILTRO DE AIRE  ALTA EFICIENCIA - CAT - KUBOTA - CASE
# 4142         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 4253         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 4275         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 4377         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 4468         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
# 4539         DA2570 FILTRO AIRE DONSSON - PERKINS, FIAT, CATERPILLAR.
#
#       costo_promedio
# 43          13771.02
# 153         13771.02
# 282         13771.02
# 366         13771.02
# 456         18775.78
# 486         13771.02
# 642         13771.02
# 726         13771.02
# 783         18775.78
# 834         13771.02
# 906         13771.02
# 1016        13771.02
# 1090        13771.02
# 1164        13771.02
# 1312        13771.02
# 1399        13771.02
# 1504        13771.02
# 1612        13771.02
# 1682        13771.02
# 1786        18775.78
# 1787        13771.02
# 1899        13771.02
# 1962        13771.02
# 2061        13771.02
# 2195        13771.02
# 2338        13771.02
# 2452        13771.02
# 2570        13771.02
# 2694        13771.02
# 2780        13771.02
# 2850        18775.78
# 2900        13771.02
# 3001        13771.02
# 3071        13771.02
# 3149        13771.02
# 3181        13771.02
# 3258        13771.02
# 3293        18775.78
# 3368        13771.02
# 3473        13771.02
# 3586        13771.02
# 3712        13771.02
# 3776        18775.78
# 3785        13771.02
# 3855        13771.02
# 3922        13771.02
# 3941        13771.02
# 3959        13771.02
# 4036        13771.02
# 4108        18775.78
# 4142        13771.02
# 4253        13771.02
# 4275        13771.02
# 4377        13771.02
# 4468        13771.02
# 4539        13771.02

# %%
ops_con_costo['diferencia'] = ops_con_costo['costo_unitario_op'] - ops_con_costo['costo_promedio']

ops_con_costo["%diferencia"] = (ops_con_costo["diferencia"] / ops_con_costo["costo_promedio"])

ops_con_costo["%_diferencia_abs"] = (ops_con_costo["diferencia"].abs() / ops_con_costo['costo_promedio'])

# %%
ops_con_costo.to_excel("ops_relacionadas.xlsx")

# %%
ops_con_costo[ops_con_costo["costo_promedio"]==0]  # Comprobamos que no quedo ninguna OP sin el costo promedio asignado
# Out:
# Empty DataFrame
# Columns: [unidades_producidas, nombre_op, costo_unitario_op, fecha_cierre_op, producto, costo_promedio, diferencia, %diferencia, %_diferencia_abs]
# Index: []

# %% [markdown]
# ### Df unido y corregido

# %%
df_unido_corr[df_unido_corr["producto_x"].str.contains("DA2983")].sample(10)
# Out:
#                              producto_x  costo_estandar_promedio  \
# 2558  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
# 2565  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
# 2557  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
# 2564  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
# 2563  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
# 2560  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
# 2559  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
# 2561  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
# 2562  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
# 2567  DA2983 FILTROAIRE MOTORES PERKINS                 10686.95
#
#       cantidad_disponible                      producto_corr  \
# 2558                248.0  DA2983 FILTROAIRE MOTORES PERKINS
# 2565                248.0  DA2983 FILTROAIRE MOTORES PERKINS
# 2557                248.0  DA2983 FILTROAIRE MOTORES PERKINS
# 2564                248.0  DA2983 FILTROAIRE MOTORES PERKINS
# 2563                248.0  DA2983 FILTROAIRE MOTORES PERKINS
# 2560                248.0  DA2983 FILTROAIRE MOTORES PERKINS
# 2559                248.0  DA2983 FILTROAIRE MOTORES PERKINS
# 2561                248.0  DA2983 FILTROAIRE MOTORES PERKINS
# 2562                248.0  DA2983 FILTROAIRE MOTORES PERKINS
# 2567                248.0  DA2983 FILTROAIRE MOTORES PERKINS
#
#                              producto_y  unidades_producidas nombre_op  \
# 2558  DA2983 FILTROAIRE MOTORES PERKINS                250.0   MO12313
# 2565  DA2983 FILTROAIRE MOTORES PERKINS                300.0   MO09266
# 2557  DA2983 FILTROAIRE MOTORES PERKINS                200.0   MO13059
# 2564  DA2983 FILTROAIRE MOTORES PERKINS                300.0   MO09748
# 2563  DA2983 FILTROAIRE MOTORES PERKINS                200.0   MO10367
# 2560  DA2983 FILTROAIRE MOTORES PERKINS                150.0   MO11704
# 2559  DA2983 FILTROAIRE MOTORES PERKINS                150.0   MO12113
# 2561  DA2983 FILTROAIRE MOTORES PERKINS                150.0   MO11292
# 2562  DA2983 FILTROAIRE MOTORES PERKINS                150.0   MO10871
# 2567  DA2983 FILTROAIRE MOTORES PERKINS                200.0   MO08426
#
#       costo_unitario_op      fecha_cierre_op _merge
# 2558           10023.63  2025-05-07 10:11:22   both
# 2565           10458.89  2023-07-26 13:46:17   both
# 2557           10804.43  2025-09-12 13:51:18   both
# 2564           10816.48  2023-11-08 09:22:11   both
# 2563           11866.00  2024-04-30 15:08:05   both
# 2560           12236.66  2024-12-27 14:55:34   both
# 2559           11036.00  2025-03-28 07:39:47   both
# 2561           10042.45  2024-09-27 15:55:31   both
# 2562           11038.63  2024-07-11 06:44:08   both
# 2567           13402.83  2023-02-04 11:57:28   both

# %%
# 1. Crear columna final de producto
df_unido_corr["producto"] = df_unido_corr["producto_corr"].fillna(df_unido_corr["producto_x"])

# 2. Eliminar columnas duplicadas
df_unido_corr = df_unido_corr.drop(columns=["producto_x", "producto_y", "producto_corr"], errors="ignore")

# 3. Eliminar duplicados de OP
df_unido_corr = df_unido_corr.drop_duplicates(subset=["nombre_op", "fecha_cierre_op", "producto"], keep="last")

# 4. Ordenar
df_limpio = df_unido_corr.sort_values(["producto", "fecha_cierre_op"], ascending=[True, False]).reset_index(drop=True)

# %%
df_limpio = df_limpio[~ (df_limpio['cantidad_disponible']==0)]  #Retirar ruido , productos sin unidades disponibles


df_limpio[df_limpio["producto"].str.contains("DA2983")]
# Out:
#       costo_estandar_promedio  cantidad_disponible  unidades_producidas  \
# 1742                 10686.95                248.0                200.0
# 1743                 10686.95                248.0                250.0
# 1744                 10686.95                248.0                150.0
# 1745                 10686.95                248.0                150.0
# 1746                 10686.95                248.0                150.0
# 1747                 10686.95                248.0                150.0
# 1748                 10686.95                248.0                200.0
# 1749                 10686.95                248.0                300.0
# 1750                 10686.95                248.0                300.0
# 1751                 10686.95                248.0                151.0
# 1752                 10686.95                248.0                200.0
#
#      nombre_op  costo_unitario_op      fecha_cierre_op _merge  \
# 1742   MO13059           10804.43  2025-09-12 13:51:18   both
# 1743   MO12313           10023.63  2025-05-07 10:11:22   both
# 1744   MO12113           11036.00  2025-03-28 07:39:47   both
# 1745   MO11704           12236.66  2024-12-27 14:55:34   both
# 1746   MO11292           10042.45  2024-09-27 15:55:31   both
# 1747   MO10871           11038.63  2024-07-11 06:44:08   both
# 1748   MO10367           11866.00  2024-04-30 15:08:05   both
# 1749   MO09748           10816.48  2023-11-08 09:22:11   both
# 1750   MO09266           10458.89  2023-07-26 13:46:17   both
# 1751   MO08876           11377.29  2023-05-17 16:02:46   both
# 1752   MO08426           13402.83  2023-02-04 11:57:28   both
#
#                                producto
# 1742  DA2983 FILTROAIRE MOTORES PERKINS
# 1743  DA2983 FILTROAIRE MOTORES PERKINS
# 1744  DA2983 FILTROAIRE MOTORES PERKINS
# 1745  DA2983 FILTROAIRE MOTORES PERKINS
# 1746  DA2983 FILTROAIRE MOTORES PERKINS
# 1747  DA2983 FILTROAIRE MOTORES PERKINS
# 1748  DA2983 FILTROAIRE MOTORES PERKINS
# 1749  DA2983 FILTROAIRE MOTORES PERKINS
# 1750  DA2983 FILTROAIRE MOTORES PERKINS
# 1751  DA2983 FILTROAIRE MOTORES PERKINS
# 1752  DA2983 FILTROAIRE MOTORES PERKINS

# %%
# ===========================
# 1) Función costo real
# ===========================
def calcular_costo_real(grupo):
    # ordenar las OP por fecha (descendente: más recientes primero)
    grupo = grupo.sort_values('fecha_cierre_op', ascending=False)

    cant_disp = grupo['cantidad_disponible'].iloc[0]
    total_tomado = 0
    costo_total = 0

    for _, row in grupo.iterrows():
        if total_tomado >= cant_disp:
            break

        # ignorar OP con costo nulo o cero
        if pd.isna(row['costo_unitario_op']) or row['costo_unitario_op'] == 0:
            continue

        # Tomar lo que falta o lo que tiene esta OP
        tomar = min(row['unidades_producidas'], cant_disp - total_tomado)

        costo_total += tomar * row['costo_unitario_op']
        total_tomado += tomar

    if total_tomado == 0:
        return None

    return costo_total / total_tomado


# ===========================
# 2) Costo real por producto
# ===========================
costo_real = (
    df_limpio
    .groupby('producto')
    .apply(calcular_costo_real)
    .reset_index()
)
costo_real.columns = ['producto', 'costo_real']


# ===========================
# 3) Última fecha de producción por producto
# ===========================
ultima_fecha = (
    df_limpio.groupby('producto')['fecha_cierre_op']
    .max()
    .reset_index()
)
ultima_fecha.columns = ['producto', 'ultima_fecha_produccion']


# ===========================
# 4) Construcción resumen
# ===========================
resumen = (
    df_limpio[['producto', 'costo_estandar_promedio', 'cantidad_disponible']]
    .drop_duplicates()
    .merge(costo_real, on='producto', how='left')
    .merge(ultima_fecha, on='producto', how='left')   # <-- se agrega la fecha
)

# Diferencia entre costo real y costo estándar
resumen['diferencia'] = resumen['costo_real'] - resumen['costo_estandar_promedio']

resumen["%diferencia"] = (resumen["diferencia"] / resumen["costo_estandar_promedio"])

resumen["%_diferencia_abs"] = (resumen["diferencia"].abs() / resumen["costo_estandar_promedio"])
# Out:
# /tmp/ipykernel_12077/3487751595.py:38: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(calcular_costo_real)

# %%
resumen[resumen["costo_real"].isna()] # es un producto que tiene existencias y tiene una op pero en ella no cargaron costo unitario ejecutado fue en 2017
# Out:
# Empty DataFrame
# Columns: [producto, costo_estandar_promedio, cantidad_disponible, costo_real, ultima_fecha_produccion, diferencia, %diferencia, %_diferencia_abs]
# Index: []

# %%
resumen[resumen["producto"].str.contains("DA4982", case=False, na=False)]
# Out:
#                                                   producto  \
# 369  DA4982 FILTRO AIRE INT. CAMION IHC 7600 MOTOR CUMMINS
#
#      costo_estandar_promedio  cantidad_disponible    costo_real  \
# 369                 24338.22                777.0  24481.565946
#
#     ultima_fecha_produccion  diferencia  %diferencia  %_diferencia_abs
# 369     2025-09-30 16:25:24  143.345946      0.00589           0.00589

# %%
resumen.to_excel("monitoreo_.xlsx")

# %%
import xmlrpc.client
import pandas as pd

username = "juan.cano@donsson.com"
password = "1000285668"
url = "https://donsson.com"
db = "Donsson_produccion"

common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
uid = common.authenticate(db, username, password, {})
models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")


# 1. Obtener las órdenes de producción ya cerradas (hechas por manufactura)
precio_estandar_historico = models.execute_kw(
    db, uid, password,
    'stock.change.standard.price', 'search_read',
    [[]],   # Todo
    {'fields': ['create_date', 'product_id', 'product_qty']}
)

# %% [markdown]
# # EQUIVALENCIAS MARCAS

# %%
import xmlrpc.client
import pandas as pd

username = "juan.cano@donsson.com"
password = "1000285668"
url = "https://donsson.com"
db = "Donsson_produccion"

common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
uid = common.authenticate(db, username, password, {})
models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")

campos = models.execute_kw(
    db, uid, password,
    'product.template', 'fields_get',
    []
)

for nombre, info in campos.items():
    if info.get('type') in ('one2many', 'many2one', 'many2many'):
        print(nombre, "->", info.get('relation'))
# Out:
# write_uid -> res.users
# property_account_income -> account.account
# website_style_ids -> product.style
# product_rate -> website.product.rate
# property_stock_account_output -> account.account
# catalogo_valvula_alivio -> catalogo.product.valvula_alivio
# company_id -> res.company
# public_categ_ids -> product.public.category
# pricelist_id -> product.pricelist
# property_stock_account_input -> account.account
# bom_ids -> mrp.bom
# classprod_id -> cs.clasprod
# catalogo_material_filtrante -> catalogo.product.material_filtrante
# alternative_product_ids -> product.template
# seller_id -> res.partner
# packaging_ids -> product.packaging
# pos_categ_id -> pos.category
# seller_ids -> product.supplierinfo
# website_message_ids -> mail.message
# catalogo_marca -> catalogo.marcas
# accessory_product_ids -> product.product
# message_follower_ids -> res.partner
# attribute_line_ids -> product.attribute.line
# asset_category_id -> account.asset.category
# images -> product.image
# catalogo_rosca -> catalogo.product.rosca
# catalogo_forma -> catalogo.product.forma
# catalogo_costruccion -> catalogo.product.construccion
# partida_id -> product.partida.arancelaria
# analytics_id -> product.account.analytic.line
# property_stock_procurement -> stock.location
# uos_id -> product.uom
# create_uid -> res.users
# product_manager -> res.users
# catalogo_uso -> catalogo.product.usos
# catalogo_direccion_filtrado -> catalogo.product.direccion_filtrado
# property_stock_production -> stock.location
# taxes_ids -> res.country.state.tax
# property_stock_inventory -> stock.location
# catalogo_nivel_consumo -> catalogo.product.nivel_consumo
# catalogo_material_tapa -> catalogo.product.material_tapa
# product_tmpl_specs_ids -> product.specification
# product_variant_ids -> product.product
# uom_id -> product.uom
# catalogo_equivalencias_reffabri -> catalogo.referencia.fabricantes
# location_id -> stock.location
# message_ids -> mail.message
# uom_po_id -> product.uom
# product_class -> product.type.class
# property_account_refund -> account.account
# store_ids -> res.store
# supplier_taxes_id -> account.tax
# categ_id -> product.category
# catalogo_aplicacion_motor -> catalogo.motor.vehiculo
# route_ids -> stock.location.route
# property_account_expense -> account.account
# taxes_id -> account.tax

# %%
import xmlrpc.client
import pandas as pd

username = "juan.cano@donsson.com"
password = "1000285668"
url = "https://donsson.com"
db = "Donsson_produccion"

common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
uid = common.authenticate(db, username, password, {})
models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")


# 1) Productos básicos
productos = models.execute_kw(
    db, uid, password,
    'product.template', 'search_read',
    [[]],
    {'fields': ['id', 'name', 'default_code']}
)
df_prod = pd.DataFrame(productos).rename(columns={
    'id': 'product_id',
    'name': 'producto_nombre',
    'default_code': 'producto_codigo'
})

# 2) Equivalencias
equivalencias = models.execute_kw(
    db, uid, password,
    'catalogo.referencia.fabricantes', 'search_read',
    [[]],
    {'fields': ['id', 'name', 'tipo_marca', 'productos_referencia']}
)
df_eq = pd.DataFrame(equivalencias)

# 3) Expandir la lista de productos_referencia
df_eq = df_eq.explode('productos_referencia')
df_eq = df_eq.rename(columns={'name': 'equivalencia_ref'})

# 4) Limpiar tipo_marca (de lista [id, nombre] → solo nombre)
df_eq['marca'] = df_eq['tipo_marca'].apply(lambda x: x[1] if isinstance(x, list) else None)
df_eq['productos_referencia'] = df_eq['productos_referencia'].astype('Int64')

# 5) Merge con productos
df_final = df_eq.merge(df_prod, left_on='productos_referencia', right_on='product_id', how='left')
df_final = df_final.dropna()

# 6) Exportar a Excel
#df_final[['producto_codigo', 'producto_nombre', 'equivalencia_ref', 'marca']].to_excel("equivalencias.xlsx", index=False)
print("✅ Archivo 'equivalencias.xlsx' generado correctamente")
# Out:
# ✅ Archivo 'equivalencias.xlsx' generado correctamente

# %%
df_final["ref_donsson"] = df_final["producto_nombre"].str.split(' ').str[0]

# %%
df_final = df_final[['ref_donsson', 'producto_nombre','producto_codigo', 'equivalencia_ref', 'marca']].sort_values(by=["ref_donsson"])

df_final[df_final.duplicated()].head(10)
# Out:
#       ref_donsson                              producto_nombre  \
# 24997      DA2042            DA2042 FILTRO AIRE 1_ CATERPILLAR
# 24994      DA2049             DA2049 FILTRO AIRE 1_CATERPILLAR
# 24993      DA2049            DA2049 FILTRO AIRE 1_ CATERPILLAR
# 65211      DA2110  DA2110 FILTRO AIRE 1_ GMC,A. CHALMER,CLARK.
# 65210      DA2110  DA2110 FILTRO AIRE 1_ GMC,A. CHALMER,CLARK.
# 24989      DA2110  DA2110 FILTRO AIRE 1_ GMC,A. CHALMER,CLARK.
# 25040      DA2124            DA2124 FILTRO AIRE 1_ CATERPILLAR
# 25041      DA2124            DA2124 FILTRO AIRE 1_ CATERPILLAR
# 27152      DA2239     DA2239 FILTRO AIRE BRIGADIER CAREPANELA.
# 66425      DA2242                DA2242 FILTRO AIRE 1_ KOMATSU
#
#       producto_codigo equivalencia_ref      marca
# 24997     DAR02042025            42378        WIX
# 24994     BAR02049125            42334        WIX
# 24993     DAR02049025            42334        WIX
# 65211     BAE02110125          P182041  DONALDSON
# 65210     DAR02110025          P182041  DONALDSON
# 24989     DAR02110025            42225        WIX
# 25040     DAR02124025            42980        WIX
# 25041     BAR02124125            42980        WIX
# 27152     BAE02239125          57MD36M       MACK
# 66425     DAR02242025            42377        WIX

# %%
df_final[df_final["producto_codigo"]=="DAR02042025"].sort_values(by=["marca"])
# Out:
#       ref_donsson                    producto_nombre producto_codigo  \
# 19217      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 35798      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 45373      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 4139       DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 4152       DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 6293       DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 9685       DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 9687       DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 12916      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 9698       DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 9700       DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 11197      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 24031      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 34679      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 16840      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 22241      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 30897      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 8920       DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 18582      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 17423      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 39883      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 41112      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 24997      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 46101      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
#
#       equivalencia_ref        marca
# 19217            AZ216        A Y Z
# 35798           PA1673      BALDWIN
# 45373           2S1288  CATERPILLAR
# 4139            1W0392  CATERPILLAR
# 4152             1W392  CATERPILLAR
# 6293            2S1636  CATERPILLAR
# 9685            4M2976  CATERPILLAR
# 9687            4M3976  CATERPILLAR
# 12916           7W3920  CATERPILLAR
# 9698            4M9378  CATERPILLAR
# 9700            4M9387  CATERPILLAR
# 11197           630710        CLARK
# 24031           DX3126      DIAMOND
# 34679          P181105    DONALDSON
# 16840            AF337   FLEETGUARD
# 22241            CA216         FRAM
# 30897          LAF7531   LUBERFINER
# 8920        4574070111   MITSUBISHI
# 18582         AP4M9378       PARTMO
# 17423           AF9378    PUROLATOR
# 39883           SFA216    SUPERFILT
# 41112            TF216     TECNIFIL
# 24997            42378          WIX
# 46101            42378          WIX

# %%
df_def = df_final.drop_duplicates()

# %%
df_def[df_def["producto_codigo"]=="DAR02042025"].sort_values(by=["marca"])
# Out:
#       ref_donsson                    producto_nombre producto_codigo  \
# 19217      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 35798      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 45373      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 4139       DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 4152       DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 6293       DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 9685       DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 9687       DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 12916      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 9698       DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 9700       DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 11197      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 24031      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 34679      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 16840      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 22241      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 30897      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 8920       DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 18582      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 17423      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 39883      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 41112      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
# 46101      DA2042  DA2042 FILTRO AIRE 1_ CATERPILLAR     DAR02042025
#
#       equivalencia_ref        marca
# 19217            AZ216        A Y Z
# 35798           PA1673      BALDWIN
# 45373           2S1288  CATERPILLAR
# 4139            1W0392  CATERPILLAR
# 4152             1W392  CATERPILLAR
# 6293            2S1636  CATERPILLAR
# 9685            4M2976  CATERPILLAR
# 9687            4M3976  CATERPILLAR
# 12916           7W3920  CATERPILLAR
# 9698            4M9378  CATERPILLAR
# 9700            4M9387  CATERPILLAR
# 11197           630710        CLARK
# 24031           DX3126      DIAMOND
# 34679          P181105    DONALDSON
# 16840            AF337   FLEETGUARD
# 22241            CA216         FRAM
# 30897          LAF7531   LUBERFINER
# 8920        4574070111   MITSUBISHI
# 18582         AP4M9378       PARTMO
# 17423           AF9378    PUROLATOR
# 39883           SFA216    SUPERFILT
# 41112            TF216     TECNIFIL
# 46101            42378          WIX

# %%
df_def.to_excel("equivalencias.xlsx", index=False)
df_def.head(20)
# Out:
#       ref_donsson                                   producto_nombre  \
# 54937      DA2001             DA2001 FILTRO AIRE 1o. CAMIONES VOLVO
# 54938      DA2001             DA2001 FILTRO AIRE 1o. CAMIONES VOLVO
# 54939      DA2001             DA2001 FILTRO AIRE 1o. CAMIONES VOLVO
# 54940      DA2001             DA2001 FILTRO AIRE 1o. CAMIONES VOLVO
# 55936      DA2001             DA2001 FILTRO AIRE 1o. CAMIONES VOLVO
# 47513      DA2002  DA2002 FILTRO AIRE CAMIONES OTTAWA MOTOR CUMMINS
# 47887      DA2002  DA2002 FILTRO AIRE CAMIONES OTTAWA MOTOR CUMMINS
# 47886      DA2002  DA2002 FILTRO AIRE CAMIONES OTTAWA MOTOR CUMMINS
# 47885      DA2002  DA2002 FILTRO AIRE CAMIONES OTTAWA MOTOR CUMMINS
# 47884      DA2002  DA2002 FILTRO AIRE CAMIONES OTTAWA MOTOR CUMMINS
# 47514      DA2002  DA2002 FILTRO AIRE CAMIONES OTTAWA MOTOR CUMMINS
# 47523      DA2003                      DA2003 FILTRO AIRE- CASE STX
# 47522      DA2003                      DA2003 FILTRO AIRE- CASE STX
# 54182      DA2003                      DA2003 FILTRO AIRE- CASE STX
# 58208      DA2004   DA2004 FILTRO AIRE DESFOGUE TANQUES HIDRAULICOS
# 68038      DA2004   DA2004 FILTRO AIRE DESFOGUE TANQUES HIDRAULICOS
# 59638      DA2004   DA2004 FILTRO AIRE DESFOGUE TANQUES HIDRAULICOS
# 68423      DA2004   DA2004 FILTRO AIRE DESFOGUE TANQUES HIDRAULICOS
# 55832      DA2004   DA2004 FILTRO AIRE DESFOGUE TANQUES HIDRAULICOS
# 55833      DA2004   DA2004 FILTRO AIRE DESFOGUE TANQUES HIDRAULICOS
#
#       producto_codigo equivalencia_ref       marca
# 54937     BAB02001125           RS3740     BALDWIN
# 54938     BAB02001125          8076195       VOLVO
# 54939     BAB02001125          P540388   DONALDSON
# 54940     BAB02001125          AF25435  FLEETGUARD
# 55936     BAB02001125          8082103       VOLVO
# 47513     BAE02002125           PA3493     BALDWIN
# 47887     BAE02002125          LAF1934  LUBERFINER
# 47886     BAE02002125          P537454   DONALDSON
# 47885     BAE02002125           CA8130        FRAM
# 47884     BAE02002125           AH1197  FLEETGUARD
# 47514     BAE02002125       114880003A        FARR
# 47523     DAB02003025          AF25710  FLEETGUARD
# 47522     DAB02003025         367340A1        CASE
# 54182     DAB02003025           RS5455     BALDWIN
# 58208     BAE02004125        31EE02110     HYUNDAI
# 68038     BAE02004125       31EE02110A     HYUNDAI
# 59638     BAE02004125          P502563   DONALDSON
# 68423     BAE02004125           A71330      SAKURA
# 55832     BAE02004125           PA5316     BALDWIN
# 55833     BAE02004125         14500233       VOLVO

# %%
df_def.isna().sum()
# Out:
# ref_donsson         0
# producto_nombre     0
# producto_codigo     0
# equivalencia_ref    0
# marca               0
# dtype: int64
