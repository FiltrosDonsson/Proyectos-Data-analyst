# %%
import xmlrpc.client
from datetime import date, timedelta
import pandas as pd

# Mostrar todas las columnas
pd.set_option('display.max_columns', None)

# Mostrar todas las filas (si quieres limitarlo, usa por ejemplo 200)
pd.set_option('display.max_rows', None)

# Ampliar el ancho de cada columna para ver bien el texto
pd.set_option('display.max_colwidth', None)

# Ajustar el ancho de la tabla en consola
pd.set_option('display.width', 0)
# ===============================
# 1. Conexión con Odoo
# ===============================

ODOO_URL = "https://www.donssonusa.com"   # 👈 IMPORTANTE: con https://
ODOO_DB = "donsson-filters-florida-llc"       # Nombre de la base
ODOO_USERNAME = "gbetancourt@donsson.com"
ODOO_PASSWORD = "DonssonFloridaCol"

# Autenticación
common = xmlrpc.client.ServerProxy(f"{ODOO_URL}/xmlrpc/2/common")
uid = common.authenticate(ODOO_DB, ODOO_USERNAME, ODOO_PASSWORD, {})

if not uid:
    print("❌ Error de autenticación. Verifica tus credenciales o el nombre de la base.")
    exit()
else:
    print(f"✅ Conectado correctamente. UID: {uid}")

# Crear conexión a modelos
models = xmlrpc.client.ServerProxy(f"{ODOO_URL}/xmlrpc/2/object")
# Out:
# ✅ Conectado correctamente. UID: 6

# %%
import xmlrpc.client

ODOO_URL = "https://www.donssonusa.com"
ODOO_DB = "donsson-filters-florida-llc"
ODOO_USERNAME = "gbetancourt@donsson.com"
ODOO_PASSWORD = "DonssonFloridaCol"

# Conexión
common = xmlrpc.client.ServerProxy(f"{ODOO_URL}/xmlrpc/2/common")
uid = common.authenticate(ODOO_DB, ODOO_USERNAME, ODOO_PASSWORD, {})
models = xmlrpc.client.ServerProxy(f"{ODOO_URL}/xmlrpc/2/object")

# Ver campos disponibles de un modelo (por ejemplo, productos)
fields = models.execute_kw(
    ODOO_DB, uid, ODOO_PASSWORD,
    'product.template', 'fields_get',
    [], {'attributes': ['string', 'type', 'required']}
)

for field, info in sorted(fields.items(), key=lambda x: x[1].get("string", "")):
    print(f"{field:40} | {info.get('type', ''):10} | {info.get('string', '')}")
# Out:
# bom_count                                | integer    | # Bill of Material
# product_variant_count                    | integer    | # Product Variants
# used_in_bom_count                        | integer    | # of BoM Where is Used
# accessory_product_ids                    | many2many  | Accessory Products
# account_tag_ids                          | many2many  | Account Tags
# message_needaction                       | boolean    | Action Needed
# active                                   | boolean    | Active
# activity_ids                             | one2many   | Activities
# activity_exception_decoration            | selection  | Activity Exception Decoration
# activity_state                           | selection  | Activity State
# activity_type_icon                       | char       | Activity Type Icon
# ebay_best_offer                          | boolean    | Allow Best Offer
# alternative_product_ids                  | many2many  | Alternative Products
# x_studio_applications                    | text       | Applications
# message_attachment_count                 | integer    | Attachment Count
# rating_avg                               | float      | Average Rating
# barcode                                  | char       | Barcode
# base_unit_count                          | float      | Base Unit Count
# base_unit_name                           | char       | Base Unit Name
# bom_ids                                  | one2many   | Bill of Materials
# bom_line_ids                             | one2many   | BoM Components
# ebay_buy_it_now_price                    | float      | Buy It Now Price
# can_image_1024_be_zoomed                 | boolean    | Can Image 1024 be zoomed
# can_publish                              | boolean    | Can Publish
# purchase_ok                              | boolean    | Can be Purchased
# sale_ok                                  | boolean    | Can be Sold
# x_studio_catalog_code                    | char       | Catalog code
# ebay_category_id                         | many2one   | Category
# ebay_category_2_id                       | many2one   | Category 2 (Optional)
# route_from_categ_ids                     | many2many  | Category Routes
# color                                    | integer    | Color Index
# company_id                               | many2one   | Company
# compare_list_price                       | monetary   | Compare to Price
# allow_out_of_stock_order                 | boolean    | Continue selling when out-of-stock
# purchase_method                          | selection  | Control Policy
# standard_price                           | float      | Cost
# cost_currency_id                         | many2one   | Cost Currency
# cost_method                              | selection  | Costing Method
# create_uid                               | many2one   | Created by
# create_date                              | datetime   | Created on
# x_studio_cross_reference                 | text       | Cross reference
# currency_id                              | many2one   | Currency
# base_unit_id                             | many2one   | Custom Unit of Measure
# sale_delay                               | integer    | Customer Lead Time
# taxes_id                                 | many2many  | Customer Taxes
# split_method_landed_cost                 | selection  | Default Split Method
# description                              | html       | Description
# ebay_template_id                         | many2one   | Description Template
# website_description                      | html       | Description for the website
# description_pickingout                   | text       | Description on Delivery Orders
# description_picking                      | text       | Description on Picking
# description_pickingin                    | text       | Description on Receptions
# display_name                             | char       | Display Name
# product_document_ids                     | one2many   | Documents
# product_document_count                   | integer    | Documents Count
# ebay_listing_duration                    | selection  | Duration
# property_account_expense_id              | many2one   | Expense Account
# product_template_image_ids               | one2many   | Extra Product Media
# priority                                 | selection  | Favorite
# fiscal_country_codes                     | char       | Fiscal Country Codes
# message_follower_ids                     | one2many   | Followers
# message_partner_ids                      | many2many  | Followers (Partners)
# virtual_available                        | float      | Forecasted Quantity
# hs_code                                  | char       | HS Code
# has_message                              | boolean    | Has Message
# id                                       | integer    | ID
# activity_exception_icon                  | char       | Icon
# image_1920                               | binary     | Image
# image_1024                               | binary     | Image 1024
# image_128                                | binary     | Image 128
# image_256                                | binary     | Image 256
# image_512                                | binary     | Image 512
# property_account_income_id               | many2one   | Income Account
# incoming_qty                             | float      | Incoming
# default_code                             | char       | Internal Reference
# property_stock_inventory                 | many2one   | Inventory Location
# valuation                                | selection  | Inventory Valuation
# invoice_policy                           | selection  | Invoicing Policy
# message_is_follower                      | boolean    | Is Follower
# is_kits                                  | boolean    | Is Kits
# is_published                             | boolean    | Is Published
# landed_cost_ok                           | boolean    | Is a Landed Cost
# has_configurable_attributes              | boolean    | Is a configurable product
# is_product_variant                       | boolean    | Is a product variant
# ebay_item_condition_id                   | many2one   | Item Condition
# write_uid                                | many2one   | Last Updated by
# write_date                               | datetime   | Last Updated on
# ebay_last_sync                           | datetime   | Last update
# ebay_listing_type                        | selection  | Listing Type
# location_id                              | many2one   | Location
# mrp_product_qty                          | float      | Manufactured
# message_has_error                        | boolean    | Message Delivery error
# purchase_line_warn_msg                   | text       | Message for Purchase Order Line
# sale_line_warn_msg                       | text       | Message for Sales Order Line
# message_ids                              | one2many   | Messages
# my_activity_date_deadline                | date       | My Activity Deadline
# name                                     | char       | Name
# nbr_moves_in                             | integer    | Nbr Moves In
# nbr_moves_out                            | integer    | Nbr Moves Out
# activity_calendar_event_id               | many2one   | Next Activity Calendar Event
# activity_date_deadline                   | date       | Next Activity Deadline
# activity_summary                         | char       | Next Activity Summary
# activity_type_id                         | many2one   | Next Activity Type
# message_needaction_counter               | integer    | Number of Actions
# message_has_error_counter                | integer    | Number of errors
# pricelist_item_count                     | integer    | Number of price rules
# offer_count                              | integer    | Offer Count
# optional_product_ids                     | many2many  | Optional Products
# country_of_origin                        | many2one   | Origin of Goods
# out_of_stock_message                     | html       | Out-of-Stock Message
# outgoing_qty                             | float      | Outgoing
# ebay_seller_payment_policy_id            | many2one   | Payment Policy
# planning_enabled                         | boolean    | Plan Services
# planning_role_id                         | many2one   | Planning Role
# property_account_creditor_price_difference | many2one   | Price Difference Account
# base_unit_price                          | monetary   | Price Per Unit
# ebay_private_listing                     | boolean    | Private Listing
# product_variant_id                       | many2one   | Product
# attribute_line_ids                       | one2many   | Product Attributes
# categ_id                                 | many2one   | Product Category
# packaging_ids                            | one2many   | Product Packages
# product_tag_ids                          | many2many  | Product Template Tags
# product_tooltip                          | char       | Product Tooltip
# detailed_type                            | selection  | Product Type
# property_stock_production                | many2one   | Production Location
# product_variant_ids                      | one2many   | Products
# product_properties                       | properties | Properties
# description_purchase                     | text       | Purchase Description
# purchase_line_warn                       | selection  | Purchase Order Line Warning
# uom_po_id                                | many2one   | Purchase UoM
# purchased_product_qty                    | float      | Purchased
# qty_available                            | float      | Quantity On Hand
# ebay_quantity                            | integer    | Quantity On eBay
# ebay_quantity_sold                       | integer    | Quantity Sold
# rating_avg_text                          | selection  | Rating Avg Text
# rating_last_feedback                     | text       | Rating Last Feedback
# rating_last_image                        | binary     | Rating Last Image
# rating_last_value                        | float      | Rating Last Value
# rating_percentage_satisfaction           | float      | Rating Satisfaction
# rating_last_text                         | selection  | Rating Text
# rating_count                             | integer    | Rating count
# rating_ids                               | one2many   | Ratings
# expense_policy                           | selection  | Re-Invoice Expenses
# visible_expense_policy                   | boolean    | Re-Invoice Policy visible
# reordering_max_qty                       | float      | Reordering Max Qty
# reordering_min_qty                       | float      | Reordering Min Qty
# nbr_reordering_rules                     | integer    | Reordering Rules
# responsible_id                           | many2one   | Responsible
# activity_user_id                         | many2one   | Responsible User
# ebay_seller_return_policy_id             | many2one   | Return Policy
# website_ribbon_id                        | many2one   | Ribbon
# route_ids                                | many2many  | Routes
# has_available_route_ids                  | boolean    | Routes can be selected on this product
# is_seo_optimized                         | boolean    | SEO optimized
# message_has_sms_error                    | boolean    | SMS Delivery error
# description_sale                         | text       | Sales Description
# sale_line_warn                           | selection  | Sales Order Line
# list_price                               | float      | Sales Price
# seo_name                                 | char       | Seo name
# sequence                                 | integer    | Sequence
# ebay_seller_shipping_policy_id           | many2one   | Shipping Policy
# show_forecasted_qty_status_button        | boolean    | Show Forecasted Qty Status Button
# show_on_hand_qty_status_button           | boolean    | Show On Hand Qty Status Button
# available_threshold                      | float      | Show Threshold
# show_availability                        | boolean    | Show availability Qty
# website_size_x                           | integer    | Size X
# website_size_y                           | integer    | Size Y
# sales_count                              | float      | Sold
# ebay_start_date                          | datetime   | Start Date
# ebay_price                               | float      | Starting Price for Auction
# ebay_store_category_id                   | many2one   | Store Category (Optional)
# ebay_store_category_2_id                 | many2one   | Store Category 2 (Optional)
# service_to_purchase                      | boolean    | Subcontract Service
# ebay_subtitle                            | char       | Subtitle
# tax_string                               | char       | Tax String
# ebay_title                               | char       | Title
# service_type                             | selection  | Track Service
# tracking                                 | selection  | Tracking
# type                                     | selection  | Type
# uom_id                                   | many2one   | Unit of Measure
# uom_name                                 | char       | Unit of Measure Name
# ebay_sync_stock                          | boolean    | Use Stock Quantity
# x_studio_use_stock_quantity              | boolean    | Use Stock Quantity
# ebay_use                                 | boolean    | Use eBay
# valid_product_template_attribute_line_ids | many2many  | Valid Product Attribute Lines
# variant_seller_ids                       | one2many   | Variant Seller
# supplier_taxes_id                        | many2many  | Vendor Taxes
# seller_ids                               | one2many   | Vendors
# website_published                        | boolean    | Visible on current website
# volume                                   | float      | Volume
# volume_uom_name                          | char       | Volume unit of measure label
# warehouse_id                             | many2one   | Warehouse
# website_id                               | many2one   | Website
# website_message_ids                      | one2many   | Website Messages
# public_categ_ids                         | many2many  | Website Product Category
# website_sequence                         | integer    | Website Sequence
# website_url                              | char       | Website URL
# website_meta_description                 | text       | Website meta description
# website_meta_keywords                    | char       | Website meta keywords
# website_meta_title                       | char       | Website meta title
# website_meta_og_img                      | char       | Website opengraph image
# weight                                   | float      | Weight
# weight_uom_name                          | char       | Weight unit of measure label
# ebay_description                         | html       | eBay Description
# ebay_fixed_price                         | float      | eBay Fixed Price
# ebay_id                                  | char       | eBay ID
# ebay_listing_status                      | char       | eBay Status
# ebay_url                                 | char       | eBay url
# description_ecommerce                    | html       | eCommerce Description
