# %% [markdown]
# ## MODELOS DISPONIBLES

# %%
#!/usr/bin/env python
import xmlrpc.client as xmlrpc 
import datetime as dt

ODOO_SERVER_USER = "juan.cano@donsson.com" #mi usuario 
ODOO_SERVER_PASSWORD = "1000285668" #mi contraseña de odoo 
ODOO_SERVER_URL = "https://donsson.com" #produccion url 
ODOO_SERVER_DATABASE = "Donsson_produccion" # 

###define los objetos del servidor#common: Establece la conexion#uid: Id del usuario en odoo#models: Modelos de odoo(tablas)
common = xmlrpc.ServerProxy("{}/xmlrpc/2/common".format(ODOO_SERVER_URL))
uid = common.authenticate(ODOO_SERVER_DATABASE, ODOO_SERVER_USER, ODOO_SERVER_PASSWORD, {})
models = xmlrpc.ServerProxy("{}/xmlrpc/2/object".format(ODOO_SERVER_URL))
l6m = (dt.datetime.today()-dt.timedelta(days=30)).strftime("%Y-%m-01 00:00:00") #1 meses antes desde hoy

#Consulta basica metodo search_read: Busca y lee la informacion
#Tabla ventas.perdidas(Esta tabla registra la causa de no venta por las cotizaciones y el punto de venta)
#filtrados por la variable l6m por el campo create_date(fecha de creacion).
#Extrae la informacion de las columnas 
#warehouse_id: id de la bodega en la tabla stock.warehouse(Almacenes)
#create_date: fecha de creacion(esta fecha es cuando se crea el registro en la base de datos )
#cliente_id: id del cliente en la tabla res.partner(Clientes)
#product_id: id del producto en la tabla product.template(Productos)
#cantidad: cantidad reportada(entero)
#cantidad_existencia:  cantidad en existencias en el momento de reporte(entero)
#cantidad_reservada: cantidad en reservas en el momento de reporte(entero)
#almacenamiento_tipo: Almacenamiento campo autocalculado en la cotizacion e ingresado desde el punto de venta (Agotado, En stock)

# Listar todos los modelos disponibles
modelos_disponibles = models.execute_kw(ODOO_SERVER_DATABASE, uid, ODOO_SERVER_PASSWORD,
    'ir.model', 'search_read',
    [[['model', 'ilike', 'cost']]],
    {'fields': ['model', 'name']}
)

for m in modelos_disponibles:
    print(m)
# Out:
# {'model': 'account.analytic.cost.ledger', 'id': 268, 'name': 'Account Analytic Cost Ledger'}
# {'model': 'account.analytic.cost.ledger.journal.report', 'id': 269, 'name': 'Account Analytic Cost Ledger For Journal Report'}
# {'model': 'cs.analisis.costo', 'id': 1088, 'name': 'Cadena de suministro analisis del nivel de servicio'}
# {'model': 'fleet.vehicle.cost', 'id': 710, 'name': 'Cost related to a vehicle'}
# {'model': 'mrp.bom.cost', 'id': 924, 'name': 'mrp.bom.cost'}
# {'model': 'mrp.bom.cost.lines', 'id': 925, 'name': 'mrp.bom.cost.lines'}
# {'model': 'mrp.costo.detallado', 'id': 1070, 'name': 'Costo detallado de la produccion'}
# {'model': 'report.account.report_analyticcostledger', 'id': 263, 'name': 'report.account.report_analyticcostledger'}
# {'model': 'report.account.report_analyticcostledgerquantity', 'id': 264, 'name': 'report.account.report_analyticcostledgerquantity'}
# {'model': 'stock.landed.cost', 'id': 611, 'name': 'Stock Landed Cost'}
# {'model': 'stock.landed.cost.lines', 'id': 612, 'name': 'Stock Landed Cost Lines'}

# %% [markdown]
# ## EXTRAER COSTO INVENTARIO

# %% [markdown]
# ### COLUMNAS ACTUALES

# %%
import xmlrpc.client
import pandas as pd

# Conexión con Odoo
username = "juan.cano@donsson.com"  # tu usuario
password = "1000285668"         # tu contraseña
url = "https://donsson.com"     # URL del servidor
db = "Donsson_produccion" # nombre de la base de datos

common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
uid = common.authenticate(db, username, password, {})
models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")




fields_info = models.execute_kw(
    db, uid, password,
    'cs.analisis.costo',  # Nombre técnico del modelo
    'fields_get',
    []
)

# Convertir a DataFrame para visualizar mejor
df_campos = pd.DataFrame.from_dict(fields_info, orient='index')
df_campos
# Out:
#                          sortable                           string  \
# create_date                  True                       Created on
# inventario_seguridad         True          Inventario de seguridad
# ano                          True                              Año
# producto_marca               True                            Marca
# stock_principal              True                  Stock principal
# producto_id                  True                      Descripcion
# semana                       True                           Semana
# almacen_id                   True                          Almacen
# acumulado_combinado          True              Acumulado combinado
# id                           True                               Id
# create_uid                   True                       Created by
# display_name                False                     Display Name
# requiere_despacho            True                Requiere despacho
# producto_costo_unitario      True                   Costo unitario
# __last_update               False                 Last Modified on
# total_emas                   True                       Total emas
# acumulado_costo              True                  Acumulado costo
# despacho                     True                         Despacho
# acumulado_desviacion_p       True  Acumulado desviacion porcentaje
# product_name                 True                         Producto
# sucursal_id                  True                         Sucursal
# acumulado_cantidad           True               Acumulado cantidad
# estado_despacho              True                  Estado despacho
# desviacion_ema               True                   Desviacion EMA
# write_date                   True                  Last Updated on
# stock_actual                 True                     Stock actual
# producto_code                True                  Codigo producto
# write_uid                    True                  Last Updated by
# ema                          True                              Ema
# clasificacion                True                    Clasificacion
# nivel_servicio               True                Nivel de servicio
# venta_costo                  True                      Venta costo
# punto_reorden                True                 Punto de reorden
# desviacion_ema_p             True        Desviacion EMA porcentaje
# total_emas_p                 True            Total emas porcentaje
# inventario_ideal             True                 Inventario ideal
# venta_costo_ema              True                  Venta costo EMA
# stock_real                   True             Stock principal real
#
#                          searchable  required  manual  readonly  \
# create_date                    True     False   False     False
# inventario_seguridad           True     False   False     False
# ano                            True     False   False     False
# producto_marca                 True     False   False     False
# stock_principal                True     False   False     False
# producto_id                    True     False   False     False
# semana                         True     False   False     False
# almacen_id                     True     False   False     False
# acumulado_combinado            True     False   False     False
# id                             True     False   False      True
# create_uid                     True     False   False     False
# display_name                  False     False   False      True
# requiere_despacho              True     False   False     False
# producto_costo_unitario        True     False   False     False
# __last_update                 False     False   False      True
# total_emas                     True     False   False     False
# acumulado_costo                True     False   False     False
# despacho                       True     False   False     False
# acumulado_desviacion_p         True     False   False     False
# product_name                   True     False   False     False
# sucursal_id                    True     False   False     False
# acumulado_cantidad             True     False   False     False
# estado_despacho                True     False   False     False
# desviacion_ema                 True     False   False     False
# write_date                     True     False   False     False
# stock_actual                   True     False   False     False
# producto_code                  True     False   False     False
# write_uid                      True     False   False     False
# ema                            True     False   False     False
# clasificacion                  True     False   False     False
# nivel_servicio                 True     False   False     False
# venta_costo                    True     False   False     False
# punto_reorden                  True     False   False     False
# desviacion_ema_p               True     False   False     False
# total_emas_p                   True     False   False     False
# inventario_ideal               True     False   False     False
# venta_costo_ema                True     False   False     False
# stock_real                     True     False   False     False
#
#                                            depends  groups  company_dependent  \
# create_date                                     []   False              False
# inventario_seguridad                            []   False              False
# ano                                             []   False              False
# producto_marca                                  []   False              False
# stock_principal                                 []   False              False
# producto_id                                     []   False              False
# semana                                          []   False              False
# almacen_id                                      []   False              False
# acumulado_combinado                             []   False              False
# id                                              []   False              False
# create_uid                                      []   False              False
# display_name                                    []   False              False
# requiere_despacho                               []   False              False
# producto_costo_unitario                         []   False              False
# __last_update            [create_date, write_date]   False              False
# total_emas                                      []   False              False
# acumulado_costo                                 []   False              False
# despacho                                        []   False              False
# acumulado_desviacion_p                          []   False              False
# product_name                                    []   False              False
# sucursal_id                                     []   False              False
# acumulado_cantidad                              []   False              False
# estado_despacho                                 []   False              False
# desviacion_ema                                  []   False              False
# write_date                                      []   False              False
# stock_actual                                    []   False              False
# producto_code                                   []   False              False
# write_uid                                       []   False              False
# ema                                             []   False              False
# clasificacion                                   []   False              False
# nivel_servicio                                  []   False              False
# venta_costo                                     []   False              False
# punto_reorden                                   []   False              False
# desviacion_ema_p                                []   False              False
# total_emas_p                                    []   False              False
# inventario_ideal                                []   False              False
# venta_costo_ema                                 []   False              False
# stock_real                                      []   False              False
#
#                               type  store translate         relation  \
# create_date               datetime   True       NaN              NaN
# inventario_seguridad         float   True       NaN              NaN
# ano                           char   True     False              NaN
# producto_marca                char   True     False              NaN
# stock_principal            integer   True       NaN              NaN
# producto_id               many2one   True       NaN  product.product
# semana                     integer   True       NaN              NaN
# almacen_id                many2one   True       NaN  stock.warehouse
# acumulado_combinado          float   True       NaN              NaN
# id                         integer   True       NaN              NaN
# create_uid                many2one   True       NaN        res.users
# display_name                  char  False     False              NaN
# requiere_despacho        selection   True       NaN              NaN
# producto_costo_unitario      float   True       NaN              NaN
# __last_update             datetime  False       NaN              NaN
# total_emas                   float   True       NaN              NaN
# acumulado_costo              float   True       NaN              NaN
# despacho                   integer   True       NaN              NaN
# acumulado_desviacion_p       float   True       NaN              NaN
# product_name                  char   True     False              NaN
# sucursal_id               many2one   True       NaN        res.store
# acumulado_cantidad           float   True       NaN              NaN
# estado_despacho          selection   True       NaN              NaN
# desviacion_ema               float   True       NaN              NaN
# write_date                datetime   True       NaN              NaN
# stock_actual               integer   True       NaN              NaN
# producto_code                 char   True     False              NaN
# write_uid                 many2one   True       NaN        res.users
# ema                          float   True       NaN              NaN
# clasificacion                 char   True     False              NaN
# nivel_servicio               float   True       NaN              NaN
# venta_costo                  float   True       NaN              NaN
# punto_reorden              integer   True       NaN              NaN
# desviacion_ema_p             float   True       NaN              NaN
# total_emas_p                 float   True       NaN              NaN
# inventario_ideal           integer   True       NaN              NaN
# venta_costo_ema              float   True       NaN              NaN
# stock_real                 integer   True       NaN              NaN
#
#                                                                  selection
# create_date                                                            NaN
# inventario_seguridad                                                   NaN
# ano                                                                    NaN
# producto_marca                                                         NaN
# stock_principal                                                        NaN
# producto_id                                                            NaN
# semana                                                                 NaN
# almacen_id                                                             NaN
# acumulado_combinado                                                    NaN
# id                                                                     NaN
# create_uid                                                             NaN
# display_name                                                           NaN
# requiere_despacho                                     [[si, Si], [no, No]]
# producto_costo_unitario                                                NaN
# __last_update                                                          NaN
# total_emas                                                             NaN
# acumulado_costo                                                        NaN
# despacho                                                               NaN
# acumulado_desviacion_p                                                 NaN
# product_name                                                           NaN
# sucursal_id                                                            NaN
# acumulado_cantidad                                                     NaN
# estado_despacho          [[completo, Completo], [parcial, Parcial], [si...
# desviacion_ema                                                         NaN
# write_date                                                             NaN
# stock_actual                                                           NaN
# producto_code                                                          NaN
# write_uid                                                              NaN
# ema                                                                    NaN
# clasificacion                                                          NaN
# nivel_servicio                                                         NaN
# venta_costo                                                            NaN
# punto_reorden                                                          NaN
# desviacion_ema_p                                                       NaN
# total_emas_p                                                           NaN
# inventario_ideal                                                       NaN
# venta_costo_ema                                                        NaN
# stock_real                                                             NaN

# %% [markdown]
# ### CARGA DATAFRAME UNIDO

# %%
import xmlrpc.client
import pandas as pd

# Conexión
username = "juan.cano@donsson.com"
password = "1000285668"
url = "https://donsson.com"
db = "Donsson_produccion"

common = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/common")
uid = common.authenticate(db, username, password, {})
models = xmlrpc.client.ServerProxy(f"{url}/xmlrpc/2/object")

# Campos a extraer
campos = [
    'producto_code',
    'almacen_id',
    'producto_costo_unitario',
    'clasificacion',
    'inventario_ideal',
    'producto_marca',
    'producto_code',
    'semana',
    'stock_actual',
    'product_name',
    'ano'
]

# Extraer en bloques
df_total = pd.DataFrame()
batch_size = 20000
offset = 0

while True:
    print(f"Cargando registros desde offset {offset}...")
    registros = models.execute_kw(
        db, uid, password,
        'cs.analisis.costo', 'search_read',
        [[]],  # Sin filtro de ciudad
        {'fields': campos, 'limit': batch_size, 'offset': offset}
    )
    
    if not registros:
        break

    df_parcial = pd.DataFrame(registros)
    df_total = pd.concat([df_total, df_parcial], ignore_index=True)
    offset += batch_size

    #demora en cargar aprox 30 seg
# Out:
# Cargando registros desde offset 0...
# Cargando registros desde offset 20000...
# Cargando registros desde offset 40000...
# Cargando registros desde offset 60000...

# %% [markdown]
# ### EXPORTAR DATAFRAME

# %%
df_total.sample(10)
# Out:
#         ano  producto_costo_unitario clasificacion product_name  stock_actual  \
# 33863  2025                 12400.00             C  DCE00641020             0
# 19842  2025                 39522.25             B  BCE00738125             3
# 4263   2025                 27329.56             C  DAE04444025             0
# 19858  2025                 43540.95             B  BCS10417125             3
# 37726  2025                 59961.38             C  BCX00134125             0
# 3164   2025                168109.77             C  BHE00688125             0
# 3444   2025                 25691.76             C  BAE04190125             0
# 20110  2025                 13886.00             C  DCE00833190             0
# 41596  2025                  4753.73             C  DLE00040150             0
# 26483  2025                     0.00             C         SCFB             0
#
#        semana producto_marca            almacen_id producto_code  \
# 33863      44          OTROS       [3, VALLADOLID]     020 A-025
# 19842      44        BALDWIN  [47, MOSTRADOR COTA]    125 PF7930
# 4263       44        DONSSON    [39, BARRANQUILLA]    025 DA4444
# 19858      44        BALDWIN  [47, MOSTRADOR COTA]   125 BF7949D
# 37726      44        BALDWIN     [42, BUCARAMANGA]    125 FB1307
# 3164       44        BALDWIN    [39, BARRANQUILLA]    125 PT9352
# 3444       44        BALDWIN    [39, BARRANQUILLA]    125 PA2836
# 20110      44      AUT*PARTS  [47, MOSTRADOR COTA]      190 G833
# 41596      44          OTROS            [4, NORTE]      150 C159
# 26483      44          False          [2, CALLE 6]         False
#
#        inventario_ideal       id
# 33863                 0  1980384
# 19842                 1  1966363
# 4263                  0  1950784
# 19858                 1  1966379
# 37726                 1  1984247
# 3164                  1  1949685
# 3444                  0  1949965
# 20110                 1  1966631
# 41596                 0  1988117
# 26483                 0  1973004

# %%
# Asegurarte de que todos los valores sean strings simples
df_total['sucursal_nombre'] = df_total['almacen_id'].apply(lambda x: x[1] if isinstance(x, list) and len(x) > 1 else None)
df_total = df_total.drop(columns=['almacen_id', 'id'])
df_total =  df_total[['sucursal_nombre','producto_marca','product_name','producto_code','clasificacion','stock_actual','inventario_ideal','producto_costo_unitario','semana','ano']]

# Exportar

semana_unica = df_total["semana"].unique()

# Validación
if len(semana_unica) != 1:
    raise ValueError(f"Hay más de una semana en los datos: {semana_unica}")

n_semana = int(semana_unica[0])

# Guardar el archivo con el nombre de la semana
ruta_guardado = f'dataset/Entrada/df_completo_semana{n_semana}.csv'
df_total.to_csv(ruta_guardado, index=False)
print(f"Archivo guardado en: {ruta_guardado}")
# Out:
# Archivo guardado en: dataset/Entrada/df_completo_semana44.csv

# %%
# Ahora sí agrupar
agrupado = df_total.groupby('sucursal_nombre')['stock_actual'].sum().reset_index()
agrupado = agrupado.sort_values(by='stock_actual', ascending=False)
print(agrupado)
# Out:
#                      sucursal_nombre  stock_actual
# 8                         VALLADOLID         39212
# 1                       BARRANQUILLA         20666
# 5                           MEDELLIN         19129
# 2                        BUCARAMANGA         17702
# 3                               CALI         14397
# 4                            CALLE 6         12583
# 7                              NORTE          6880
# 6                     MOSTRADOR COTA          4373
# 0  ANTIOQUEÑA DE LUBRICANTES SGP SAS           779
